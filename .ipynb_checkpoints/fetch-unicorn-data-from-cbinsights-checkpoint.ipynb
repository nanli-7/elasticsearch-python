# %% [markdown]
# # Loading Related Modules

# %%
import json
import logging
from pprint import pprint
from time import sleep
import re

# %%
import requests
from lxml import html
from bs4 import BeautifulSoup
from elasticsearch import Elasticsearch

# %% [markdown]
# # Scraping Webpage

# %%
url = 'https://www.cbinsights.com/research-unicorn-companies'
req = requests.get(url)
page = req.text
soup = BeautifulSoup(page, 'lxml')
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="" name="iy453p9485yheisruhs5"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <title>
#    The Complete List of Unicorn Companies
#   </title>
#   <meta content="A unicorn company is a startup with a valuation over $1 billion. This is an ongoing list of all unicorn companies in the U.S. and abroad.  " name="description"/>
#   <meta content="unicorn companies, billion dollar startups, unicorn startups" name="keywords"/>
#   <link href="https://www.cbinsights.com/research-unicorn-companies" rel="canonical"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="article" property="og:type"/>
#   <meta content="The Complete List of Unicorn Companies" property="og:title"/>
#   <meta content="A unicorn company is a startup with a valuation over $1 billion. This is an ongoing list of all unicorn companies in the U.S. and abroad.  " property="og:description"/>
#   <meta content="The Complete List of Unicorn Companies" property="og:site_name"/>
#   <meta content="http://instapage.cbinsights.com/research-unicorn-companies" property="og:url"/>
#   <!-- F_INSTAPAGE[dynamic_text_replacement] -->
#   <!-- font injector -->
#   <link href="//v.fastcdn.co/f/css?family=Roboto:400,100,300,100italic,300italic,400italic,500,500italic,700,700italic,900,900italic" media="screen, print" rel="stylesheet" type="text/css"/>
#   <!-- end -->
#   <style media="screen" type="text/css">
#    .page-element .btn,
# 				.page-element .contents,
# 				.page-element.widget-form form,
# 				.page-element.widget-form form input,
# 				.page-element.widget-form form textarea,
# 				.page-element.widget-form form select,
# 				.page-element.widget-form form label
# 				{
# 																	font-family: Roboto;
# 												font-weight: 400;
# 															}
#
# 				.page-element.widget-headline .contents h1,
# 				.page-element.widget-headline .contents h2,
# 				.page-element.widget-headline .contents h3,
# 				.page-element.widget-headline .contents h4,
# 				.page-element.widget-headline .contents h5,
# 				.page-element.widget-headline .contents h6
# 				{
# 																	font-family: Roboto;
# 												font-weight: 500;
# 															}
#
# 				[id^=___plusone] { width:51px !important; }
#
# 				div.social.lines [id^=___plusone] { width:62px !important; }
# 				div.social.lines span[class^=IN-widget] { min-width:70px !important; }
# 				div.social.buttons [id^=___plusone] { width:36px !important; }
# 				div.social.buttons div[class^=fb-like] { width:58px !important; }
# 				div.social.tiles [id^=___plusone] { height:63px !important; margin-top: 2px !important; }
# 				div.social.tiles .fb-like iframe { margin-top: 1px !important; }
#
# 				.widget-testimonial.style-1 .contents div.testimonial-text
# 				{
# 					margin-top: 0;
# 				}
#
# 				@media screen and (max-width: 768px)
# 				{
# 					.notification > .notification-inner
# 					{
# 						width: auto;
# 						position: fixed;
# 						top: 40%;
# 						left: 1em !important;
# 						right: 1em !important;
# 						font-size: 24px;
# 					}
# 				}
#
#
# 				/* Safari only fix */
# 				@media screen and (min-color-index:0) and(-webkit-min-device-pixel-ratio:0) {
# 				{
# 					.widget-form .select-outer select
# 					{
# 						padding-left: 10px;
# 					}
#
# 					.widget-form.mobile-form .select-outer select
# 					{
# 						padding-left: 10px;
# 					}
# 				}}
#   </style>
#   <link href="https://v.fastcdn.co/a/c112ede04e2ae4e11edaec7794665eb3029cafdf/pageserver.page2.289618503fe52f8cec7bd105150bcdea.css" rel="stylesheet" type="text/css"/>
#   <script>
#    __a_o__ = {"hasPopup":false,"isMobile":false};function getOption(k, v) { return __a_o__[k] || v; }
#   </script>
#   <script src="https://v.fastcdn.co/a/c112ede04e2ae4e11edaec7794665eb3029cafdf/pageserver.page2.es5.04a98a41f7c910412e46.bundle.js" type="text/javascript">
#   </script>
#   <meta content="width=device-width, initial-scale=1.0" id="mobile-viewport" name="viewport"/>
#   <script class="instapage-noscrap" type="text/javascript">
#    window.__page_id = 333259;
# 			window.__version = 1163;
# 			window.__variant = 'A';
# 			window.__variant_custom_name = '' || 'A';
# 			window.__is_tablet = false;
# 			window.__page_domain = '//instapage.cbinsights.com';
# 			window.__instapage_services = '//app.instapage.com';
# 			window.__instapage_proxy_services = 'PROXY_SERVICES';
# 			window.__preview = false;
# 			window.__facebook = false;
# 			window.__page_type = 2;
# 			window.__mobile_version = 2;
# 			window.__variant_hash = "4063c28f78d4345577c5ed6a00fb1b3e451b9c45";
# 			window.__predator_throttle = 10;
# 			window.__predator_blacklist = [];
# 			window.__google_tab_manager_id = "GTM-MS68MJS";
# 			window.__facebook_pixel_id = "false";
#
#
# 							window.__instapage_submission_endpoint = '//d.fastcdn.co/submissions';
#
# 			var page_version = 1163;
#
# 			var _Translate = new Translate();
#
# 			if( ijQuery === 'undefined' )
# 			{
# 				var ijQuery = jQuery;
# 			}
#
# 			window.__recaptchaError = function()
# 			{
# 				console.error( 'ReCaptcha invalid site key' );
# 				window.__reCaptchaCorrupted = true;
# 			};
#
# 			window.__removeReCaptchaClasses = function()
# 			{
# 				var challengeContainer = document.querySelector( 'iframe[src*="recaptcha"]' );
# 				var htmlDocument = document.querySelector( 'html' );
# 				htmlDocument.classList.remove( 'hasRecaptcha' );
# 				if( challengeContainer && challengeContainer.parentNode ) {
# 					challengeContainer.parentNode.classList.remove( 'recaptchaContainer' );
# 					challengeContainer.parentNode.parentNode.classList.remove( 'recaptchaWrapper' );
# 				}
# 			}
#
# 			window.__changeReCaptchaChallengePosition = function()
# 			{
# 				var challengeContainer = document.querySelector( 'iframe[src*="recaptcha/api2/bframe"]' );
#
# 				if ( challengeContainer && challengeContainer.parentNode )
# 				{
# 					try
# 					{
# 						var isSafari = navigator.vendor && navigator.vendor.indexOf( 'Apple' ) > -1 &&
#                         navigator.userAgent && !navigator.userAgent.match( 'CriOS' );
#
#          		var isiOS = !!navigator.platform && /iPad|iPhone|iPod/.test(navigator.platform);
#
# 						if(isSafari && isiOS) {
# 							var interval = setInterval(function() {
# 								var currentContainer = document.querySelector( 'iframe[src*="recaptcha/api2/bframe"]' );
#
# 								if ( !currentContainer ) {
# 									clearInterval(interval);
# 									return;
# 								}
#
# 								var challengeContainerWrapper = currentContainer.parentNode;
# 								var isContainerVisible = challengeContainerWrapper && challengeContainerWrapper.parentNode.style.visibility === 'visible';
#
# 								if (isContainerVisible) {
# 									var htmlDocument = document.querySelector('html');
# 									htmlDocument.classList.add('hasRecaptcha');
# 									currentContainer.parentNode.classList.add('recaptchaContainer');
# 									currentContainer.parentNode.parentNode.classList.add('recaptchaWrapper');
#
# 									clearInterval(interval);
# 								}
# 							}, 300);
# 						}
#
# 						challengeContainer.parentNode.style.position = 'fixed';
# 						challengeContainer.parentNode.style.margin = '0 auto';
# 					}
# 					catch( e )
# 					{
# 					}
# 				}
# 			}
#
# 			window.__reCaptchaTrigger = function( token )
# 			{
# 				_form_controller.onRecaptchaFormSubmit( token );
# 				window.__removeReCaptchaClasses();
# 			};
#
# 			ijQuery(document).ready(function()
# 			{
# 				window._Mobile_helper = new MobileHelper();
# 				window._Mobile_helper.initViewport( 960, true );
#
# 				try
# 				{
# 					ijQuery('input, textarea').placeholder();
# 				}
# 				catch( e )
# 				{
# 				}
# 			});
#
# 			ijQuery( window ).load( function()
# 			{
# 				var notification_loader;
#
# 								ijQuery( 'body' ).hide().show();
#
# 								notification_loader = ijQuery( '.notification-loader' );
# 				notification_loader.attr( 'src', notification_loader.attr( 'rel' ) );
# 			});
#
# 			_Translate.set( "Problem loading google map", "Problem loading google map" );
#
# 			is_new_mobile_visible = function()
# 			{
# 				if( !window.matchMedia )
# 				{
# 					return false;
# 				}
# 				return window.matchMedia('screen and (max-width: 620px), screen and (max-width: 999px) and (-webkit-min-device-pixel-ratio: 1.5)').matches;
# 			}
#   </script>
#   <link href="//dfsm9194vna0o.cloudfront.net/436357-0-cbismalllogoheader.png" rel="shortcut icon" type="image/ico"/>
#   <style type="text/css">
#    html
# 				{
# 					height: 100%;
# 				};
#   </style>
#   <script type="text/javascript">
#    setTimeout(function()
# 				{
# 					"use strict";
# 					try
# 					{
# 						var body = document.body;
# 						var html = document.documentElement;
# 						var height = Math.max( body.scrollHeight, body.offsetHeight, html.clientHeight, html.scrollHeight, html.offsetHeight );
#
# 						html.style.setProperty( 'height', height + 'px' );
# 					}
# 					catch( e )
# 					{
# 					}
# 				}, 1 );
#   </script>
#   <style type="text/css">
#    body
# 				{
# 					background-color: #f4f4f4;
#
# 																		background-position: top left;
#
# 					background-repeat: repeat;
# 																		background-size: cover;
# 													-webkit-background-size: cover;
# 													-moz-background-size: cover;
# 													-o-background-size: cover;
#
# 				}
#
#
# 				.page .page-block .block-inner { background-color: transparent; }
#   </style>
#   <style type="text/css">
#    #element-16
# {
# 	height: 20px;
# 	width: 370px;
# 	left: 568px;
# 	top: 21px;
# 	z-index: 3;
# }
#
# #element-16 p, #element-16 ul, #element-16 ol, #element-16 h1
# {
# 	font-size: 14px;
# 	color: rgb(0, 0, 0);
# 	line-height: 20px;
# 	text-align: right;
# }
#
# #element-32
# {
# 	height: 490px;
# 	width: 924px;
# 	left: 17px;
# 	top: 129px;
# 	z-index: 4;
# }
#
# #element-18
# {
# 	height: 59px;
# 	width: 498px;
# 	left: 105px;
# 	top: 118px;
# 	z-index: 5;
# }
#
# #element-1292
# {
# 	height: 70px;
# 	width: 638px;
# 	left: 76px;
# 	top: 31px;
# 	z-index: 6;
# }
#
# #element-1292 p, #element-1292 ul, #element-1292 ol, #element-1292 h1
# {
# 	font-size: 50px;
# 	color: rgb(255, 255, 255);
# 	line-height: 70px;
# 	text-align: left;
# }
#
# #element-1291
# {
# 	height: 34px;
# 	width: 368px;
# 	left: 76px;
# 	top: 130px;
# 	z-index: 7;
# }
#
# #element-1291 p, #element-1291 ul, #element-1291 ol, #element-1291 h1
# {
# 	font-size: 17px;
# 	color: rgb(255, 255, 255);
# 	line-height: 34px;
# 	text-align: left;
# }
#
# #element-1293
# {
# 	height: 170px;
# 	width: 602px;
# 	left: 76px;
# 	top: 101px;
# 	z-index: 8;
# }
#
# #element-1293 p, #element-1293 ul, #element-1293 ol, #element-1293 h1
# {
# 	font-size: 24px;
# 	color: rgb(0, 0, 0);
# 	line-height: 34px;
# 	text-align: left;
# }
#
# #element-1294
# {
# 	height: 238px;
# 	width: 218px;
# 	left: 666px;
# 	top: 41px;
# 	z-index: 9;
# }
#
# #element-1294 img
# {
# 	width: 216px;
# 	height: 238px;
# }
#
# #element-1300
# {
# 	height: 78px;
# 	width: 290px;
# 	left: 332px;
# 	top: 2px;
# 	z-index: 10;
# }
#
# #element-1300 img
# {
# 	width: 296px;
# 	height: 79px;
# }
#
# #element-1304
# {
# 	height: 70px;
# 	width: 748px;
# 	left: 106px;
# 	top: 36px;
# 	z-index: 11;
# }
#
# #element-1304 p, #element-1304 ul, #element-1304 ol, #element-1304 h1
# {
# 	font-size: 22px;
# 	color: rgb(55, 70, 90);
# 	line-height: 35px;
# 	text-align: center;
# }
#
# #element-1305
# {
# 	height: 38px;
# 	width: 370px;
# 	left: 17px;
# 	top: 12px;
# 	z-index: 12;
# }
#
# #element-1305 p, #element-1305 ul, #element-1305 ol, #element-1305 h1
# {
# 	font-size: 24px;
# 	color: rgb(55, 70, 90);
# 	line-height: 38px;
# 	text-align: left;
# }
#
# #element-1306
# {
# 	height: 52px;
# 	width: 924px;
# 	left: 17px;
# 	top: 58px;
# 	z-index: 13;
# }
#
# #element-1306 p, #element-1306 ul, #element-1306 ol, #element-1306 h1
# {
# 	font-size: 16px;
# 	color: rgb(55, 70, 90);
# 	line-height: 26px;
# 	text-align: left;
# }
#
#
# #page-block-0e0wkiaq9yk { height: 41px; }
# #page-block-0e0wkiaq9yk .border-holder
# {
# 			background-image: none;
#
# 			background-color: rgba(0,0,0,0);
#
# 	background-repeat: repeat;						background-position: top left;
#
# 										background-size:cover;
# 							-webkit-background-size:cover;
# 							-moz-background-size:cover;
# 							-o-background-size:cover;
#
#
# 		width: auto;
# 		border-width: 0;
# 		border-top-width: 0px;
# 		border-bottom-width: 0px;
#
#
# 	height: 41px;
#
# 	}
#
# @media only screen and (max-width: 770px) {
# 	.border-holder {
# 		background-attachment: scroll !important;
# 	}
# }
#
# #page-block-0e0wkiaq9yk .color-overlay
# {
# 						width: 100%;
# 				height: 100%;
# 		position: absolute;
# 		margin: 0 auto;
# 		background-color: rgba(0,0,0,0);
# 		opacity: 0.5;
# 		display: block;
# 	}
#
# 	#page-block-0e0wkiaq9yk .block-inner
# 	{
# 		margin-top: 0px;
# 		height: calc(100% + 0px);
# 			}
#
# #page-block-m5ywl8e5c23xr { height: 74px; }
# #page-block-m5ywl8e5c23xr .border-holder
# {
# 			background-image: none;
#
# 			background-color: #bbdbe5;
#
# 	background-repeat: repeat;						background-position: top left;
#
# 										background-size:cover;
# 							-webkit-background-size:cover;
# 							-moz-background-size:cover;
# 							-o-background-size:cover;
#
#
# 		width: 960px;
# 		margin: 0 auto;
# 		border-width: 0px;
#
#
# 	height: 74px;
#
# 	}
#
# @media only screen and (max-width: 770px) {
# 	.border-holder {
# 		background-attachment: scroll !important;
# 	}
# }
#
# #page-block-m5ywl8e5c23xr .color-overlay
# {
# 						width: 960px;
# 			left: 0;
# 			right: 0;
# 				height: 100%;
# 		position: absolute;
# 		margin: 0 auto;
# 		background-color: rgba(0,0,0,0);
# 		opacity: 0.5;
# 		display: block;
# 	}
#
# 	#page-block-m5ywl8e5c23xr .block-inner
# 	{
# 		margin-top: 0px;
# 		height: calc(100% + 0px);
# 					margin-left: 0px;
# 			}
#
# #page-block-20h8hausjmsiqkt9 { height: 310px; }
# #page-block-20h8hausjmsiqkt9 .border-holder
# {
# 			background-image: none;
#
# 			background-color: #bbdbe5;
#
# 	background-repeat: no-repeat;						background-position: left bottom;
#
# 										background-size:auto auto;
# 							-webkit-background-size:auto auto;
# 							-moz-background-size:auto auto;
# 							-o-background-size:auto auto;
#
#
# 		width: 960px;
# 		margin: 0 auto;
# 		border-width: 0px;
#
#
# 	height: 310px;
#
# 	}
#
# @media only screen and (max-width: 770px) {
# 	.border-holder {
# 		background-attachment: scroll !important;
# 	}
# }
#
# #page-block-20h8hausjmsiqkt9 .color-overlay
# {
# 			display: none;
# 	}
#
# 	#page-block-20h8hausjmsiqkt9 .block-inner
# 	{
# 		margin-top: 0px;
# 		height: calc(100% + 0px);
# 					margin-left: 0px;
# 			}
#
# #page-block-qcm8zm0lvk { height: 220px; }
# #page-block-qcm8zm0lvk .border-holder
# {
# 			background-image: none;
#
# 			background-color: #003366;
#
# 	background-repeat: repeat;						background-position: top left;
#
# 										background-size:cover;
# 							-webkit-background-size:cover;
# 							-moz-background-size:cover;
# 							-o-background-size:cover;
#
#
# 		width: 960px;
# 		margin: 0 auto;
# 		border-width: 0px;
#
#
# 	height: 220px;
#
# 	}
#
# @media only screen and (max-width: 770px) {
# 	.border-holder {
# 		background-attachment: scroll !important;
# 	}
# }
#
# #page-block-qcm8zm0lvk .color-overlay
# {
# 						width: 960px;
# 			left: 0;
# 			right: 0;
# 				height: 100%;
# 		position: absolute;
# 		margin: 0 auto;
# 		background-color: rgba(0,0,0,0);
# 		opacity: 0.5;
# 		display: block;
# 	}
#
# 	#page-block-qcm8zm0lvk .block-inner
# 	{
# 		margin-top: 0px;
# 		height: calc(100% + 0px);
# 					margin-left: 0px;
# 			}
#
# #page-block-itl8a5r5j7adobt9 { height: 17840px; }
# #page-block-itl8a5r5j7adobt9 .border-holder
# {
# 			background-image: none;
#
# 			background-color: #ffffff;
#
# 	background-repeat: repeat;						background-position: top left;
#
# 										background-size:cover;
# 							-webkit-background-size:cover;
# 							-moz-background-size:cover;
# 							-o-background-size:cover;
#
# 			border-color: #dddddd;		border-style: solid;
# 		width: 960px;
# 		margin: 0 auto;
# 		border-width: 1px;
#
#
# 	height: 17840px;
#
# 	}
#
# @media only screen and (max-width: 770px) {
# 	.border-holder {
# 		background-attachment: scroll !important;
# 	}
# }
#
# #page-block-itl8a5r5j7adobt9 .color-overlay
# {
# 			display: none;
# 	}
#
# 	#page-block-itl8a5r5j7adobt9 .block-inner
# 	{
# 		margin-top: -1px;
# 		height: calc(100% + 2px);
# 					margin-left: -1px;
# 			}
#
# #page-block-q6nkvc1zwsbawcdi { height: 51px; }
# #page-block-q6nkvc1zwsbawcdi .border-holder
# {
# 			background-image: none;
#
# 			background-color: #bbdbe5;
#
# 	background-repeat: repeat;						background-position: top left;
#
# 										background-size:cover;
# 							-webkit-background-size:cover;
# 							-moz-background-size:cover;
# 							-o-background-size:cover;
#
#
# 		width: 960px;
# 		margin: 0 auto;
# 		border-width: 0px;
#
#
# 	height: 51px;
#
# 	}
#
# @media only screen and (max-width: 770px) {
# 	.border-holder {
# 		background-attachment: scroll !important;
# 	}
# }
#
# #page-block-q6nkvc1zwsbawcdi .color-overlay
# {
# 			display: none;
# 	}
#
# 	#page-block-q6nkvc1zwsbawcdi .block-inner
# 	{
# 		margin-top: 0px;
# 		height: calc(100% + 0px);
# 					margin-left: 0px;
# 			}
#
# @media
# screen and (max-width: 620px),
# screen and (max-width: 999px) and (-webkit-min-device-pixel-ratio: 1.5) and ( max-device-width: 1280px ) and (max-device-height: 720px),
# screen and (max-width: 999px) and (-webkit-min-device-pixel-ratio: 1.5) and ( max-device-width: 1000px )
# {
# 	body
# 	{
# 		min-width: 400px;
# 		width: 100%;
# 	}
# 	.page.page2
# 	{
# 		width: 100%;
# 	}
# 	.page.page2 .block-inner
# 	{
# 		width: 400px;
# 		margin: 0 auto;
# 	}
# 	.page.page2.new-mobile-preview .block-inner
# 	{
# 		width: auto;
# 	}
#
#
# 		.widget-form .field-checkbox .field-element label:before,
# 	.widget-form .field-radio .field-element label:before
# 	{
# 		top: 16px;
# 	}
# 	.widget-form .field-checkbox .field-element label:after
# 	{
# 		top: 21px;
# 	}
#
# 	.widget-form .field-radio .field-element label:after
# 	{
# 		top: 16px;
# 	}
#
# 	.widget-form .select-outer
# 	{
# 		overflow: hidden;
# 		-webkit-border-radius: 2px;
# 		border-radius: 2px;
# 	}
#
# 	.widget-form .select-outer select
# 	{
# 		width: calc( 100% - 1px );
# 		height: 56px;
# 		border: 0;
# 		margin-bottom: 8px;
# 		margin-top: 8px;
# 		-webkit-appearance: none;
# 		line-height: 30px;
# 		border-style: solid;
# 		border-width: 1px;
# 		background-image: url( '//v.fastcdn.co/a/1488288753_select-arrow-drop-down.png' );
# 		background-position: right;
# 		background-repeat: no-repeat;
# 	}
# 	.widget-form .form-input[type="text"],
# 	.widget-form .form-input[type="password"],
# 	.widget-form .form-input[type="email"],
# 	.widget-form textarea.form-input
# 	{
# 		padding-top: 12px;
# 		padding-bottom: 9px;
# 		font-size: 20px;
# 		line-height: 22px;
# 		height: 56px;
# 		-webkit-appearance: none;
# 	}
#
# 	.widget-form .label-outside,
# 	.widget-form .outside-top,
# 	.widget-form .field-element label
# 	{
# 		font-size: 20px;
# 		line-height: 22px;
# 		padding-top: 12px;
# 		padding-bottom: 9px;
# 	}
#
# 	.widget-form select
# 	{
# 		font-size: 20px;
# 		height: 56px;
# 		padding-left: 9px;
# 		width: calc( 100% + 2px );
# 		-moz-padding-start: 5px;
# 	}
#
# 	.widget-form .input-holder.field-checkbox > label.outside-top,
# 	.widget-form .input-holder.field-radio > label.outside-top,
# 	.widget-form .field-container.edit.field-checkbox > label.label-outside,
# 	.widget-form .field-container.edit.field-radio > label.label-outside
# 	{
# 		margin-top: 8px;
# 		margin-bottom: 2px;
# 	}
#
# 	.widget-form .form-option-element label,
# 	.widget-form .field-element label
# 	{
# 		font-size: 20px;
# 		line-height: 22px;
# 		padding-bottom: 0;
# 		margin-bottom: 0px;
# 	}
#
# 	.new_mobile .widget-form textarea.form-input.shortnice
# 	{
# 		height: 56px;
# 	}
#
#
# #element-1300
# {
# 	height: 86.74px;
# 	width: 325px;
# 	left: 37px;
# 	top: -2px;
# 	z-index: 10;
# }
#
# #element-1300 img
# {
# 	width: 325px;
# 	height: 86.74px;
# }
#
# #element-1292
# {
# 	height: 76px;
# 	width: 261px;
# 	left: 58px;
# 	top: 11px;
# 	z-index: 6;
# }
#
# #element-1292 p, #element-1292 ul, #element-1292 ol, #element-1292 h1
# {
# 	font-size: 32px;
# 	color: rgb(255, 255, 255);
# 	line-height: 38px;
# 	text-align: left !important;
# }
#
# #element-1294
# {
# 	height: 82.64px;
# 	width: 75px;
# 	left: 265px;
# 	top: 7px;
# 	z-index: 9;
# }
#
# #element-1294 img
# {
# 	width: 75px;
# 	height: 82.64px;
# }
#
# #element-1293
# {
# 	height: 168px;
# 	width: 360px;
# 	left: 20px;
# 	top: 105px;
# 	z-index: 8;
# }
#
# #element-1293 p, #element-1293 ul, #element-1293 ol, #element-1293 h1
# {
# 	font-size: 20px;
# 	color: rgb(0, 0, 0);
# 	line-height: 24px;
# 	text-align: left;
# }
#
# #element-1291
# {
# 	height: 31px;
# 	width: 360px;
# 	left: 20px;
# 	top: 298px;
# 	z-index: 7;
# }
#
# #element-1291 p, #element-1291 ul, #element-1291 ol, #element-1291 h1
# {
# 	font-size: 17px;
# 	color: rgb(255, 255, 255);
# 	line-height: 31px;
# 	text-align: left;
# }
#
# #element-1304
# {
# 	height: 81px;
# 	width: 360px;
# 	left: 20px;
# 	top: 40px;
# 	z-index: 11;
# }
#
# #element-1304 p, #element-1304 ul, #element-1304 ol, #element-1304 h1
# {
# 	font-size: 19px;
# 	color: rgb(55, 70, 90);
# 	line-height: 27px;
# 	text-align: center;
# }
#
# #element-18
# {
# 	height: 72px;
# 	width: 360px;
# 	left: 20px;
# 	top: 147px;
# 	z-index: 5;
# }
#
# #element-1305
# {
# 	height: 28px;
# 	width: 360px;
# 	left: 19px;
# 	top: 18px;
# 	z-index: 12;
# }
#
# #element-1305 p, #element-1305 ul, #element-1305 ol, #element-1305 h1
# {
# 	font-size: 20px;
# 	color: rgb(55, 70, 90);
# 	line-height: 28px;
# 	text-align: left;
# }
#
# #element-1306
# {
# 	height: 132px;
# 	width: 360px;
# 	left: 19px;
# 	top: 59px;
# 	z-index: 13;
# }
#
# #element-1306 p, #element-1306 ul, #element-1306 ol, #element-1306 h1
# {
# 	font-size: 16px;
# 	color: rgb(55, 70, 90);
# 	line-height: 22px;
# 	text-align: left;
# }
#
# #element-32
# {
# 	height: 490px;
# 	width: 360px;
# 	left: 19px;
# 	top: 231px;
# 	z-index: 4;
# }
#
# #element-16
# {
# 	height: 17px;
# 	width: 360px;
# 	left: 24px;
# 	top: 20px;
# 	z-index: 3;
# }
#
# #element-16 p, #element-16 ul, #element-16 ol, #element-16 h1
# {
# 	font-size: 14px;
# 	color: rgb(0, 0, 0);
# 	line-height: 17px;
# 	text-align: right;
# }
#
#
# #page-block-0e0wkiaq9yk { height: 26px; }
# #page-block-0e0wkiaq9yk .border-holder
# {
# 			background-image: none;
#
# 			background-color: rgba(0,0,0,0);
#
# 	background-repeat: repeat;						background-position: top left;
#
# 										background-size:cover;
# 							-webkit-background-size:cover;
# 							-moz-background-size:cover;
# 							-o-background-size:cover;
#
#
# 		width: auto;
# 		border-width: 0;
# 		border-top-width: 0px;
# 		border-bottom-width: 0px;
#
#
# 	height: 26px;
#
# 	}
#
# @media only screen and (max-width: 770px) {
# 	.border-holder {
# 		background-attachment: scroll !important;
# 	}
# }
#
# #page-block-0e0wkiaq9yk .color-overlay
# {
# 						width: 100%;
# 				height: 100%;
# 		position: absolute;
# 		margin: 0 auto;
# 		background-color: rgba(0,0,0,0);
# 		opacity: 0.5;
# 		display: block;
# 	}
#
# 	#page-block-0e0wkiaq9yk .block-inner
# 	{
# 		margin-top: 0px;
# 		height: calc(100% + 0px);
# 			}
#
# #page-block-m5ywl8e5c23xr { height: 78px; }
# #page-block-m5ywl8e5c23xr .border-holder
# {
# 			background-image: none;
#
# 			background-color: #bbdbe5;
#
# 	background-repeat: repeat;						background-position: top left;
#
# 										background-size:cover;
# 							-webkit-background-size:cover;
# 							-moz-background-size:cover;
# 							-o-background-size:cover;
#
#
# 		width: 400px;
# 		margin: 0 auto;
# 		border-width: 0px;
#
#
# 	height: 78px;
#
# 	}
#
# @media only screen and (max-width: 770px) {
# 	.border-holder {
# 		background-attachment: scroll !important;
# 	}
# }
#
# #page-block-m5ywl8e5c23xr .color-overlay
# {
# 						width: 400px;
# 			left: 0;
# 			right: 0;
# 				height: 100%;
# 		position: absolute;
# 		margin: 0 auto;
# 		background-color: rgba(0,0,0,0);
# 		opacity: 0.5;
# 		display: block;
# 	}
#
# 	#page-block-m5ywl8e5c23xr .block-inner
# 	{
# 		margin-top: 0px;
# 		height: calc(100% + 0px);
# 					margin-left: 0px;
# 			}
#
# #page-block-20h8hausjmsiqkt9 { height: 360px; }
# #page-block-20h8hausjmsiqkt9 .border-holder
# {
# 			background-image: none;
#
# 			background-color: #bbdbe5;
#
# 	background-repeat: no-repeat;						background-position: left bottom;
#
# 										background-size:auto auto;
# 							-webkit-background-size:auto auto;
# 							-moz-background-size:auto auto;
# 							-o-background-size:auto auto;
#
#
# 		width: 400px;
# 		margin: 0 auto;
# 		border-width: 0px;
#
#
# 	height: 360px;
#
# 	}
#
# @media only screen and (max-width: 770px) {
# 	.border-holder {
# 		background-attachment: scroll !important;
# 	}
# }
#
# #page-block-20h8hausjmsiqkt9 .color-overlay
# {
# 			display: none;
# 	}
#
# 	#page-block-20h8hausjmsiqkt9 .block-inner
# 	{
# 		margin-top: 0px;
# 		height: calc(100% + 0px);
# 					margin-left: 0px;
# 			}
#
# #page-block-qcm8zm0lvk { height: 371px; }
# #page-block-qcm8zm0lvk .border-holder
# {
# 			background-image: none;
#
# 			background-color: #003366;
#
# 	background-repeat: repeat;						background-position: top left;
#
# 										background-size:cover;
# 							-webkit-background-size:cover;
# 							-moz-background-size:cover;
# 							-o-background-size:cover;
#
#
# 		width: 400px;
# 		margin: 0 auto;
# 		border-width: 0px;
#
#
# 	height: 371px;
#
# 	}
#
# @media only screen and (max-width: 770px) {
# 	.border-holder {
# 		background-attachment: scroll !important;
# 	}
# }
#
# #page-block-qcm8zm0lvk .color-overlay
# {
# 						width: 400px;
# 			left: 0;
# 			right: 0;
# 				height: 100%;
# 		position: absolute;
# 		margin: 0 auto;
# 		background-color: rgba(0,0,0,0);
# 		opacity: 0.5;
# 		display: block;
# 	}
#
# 	#page-block-qcm8zm0lvk .block-inner
# 	{
# 		margin-top: 0px;
# 		height: calc(100% + 0px);
# 					margin-left: 0px;
# 			}
#
# #page-block-itl8a5r5j7adobt9 { height: 20127px; }
# #page-block-itl8a5r5j7adobt9 .border-holder
# {
# 			background-image: none;
#
# 			background-color: #ffffff;
#
# 	background-repeat: repeat;						background-position: top left;
#
# 										background-size:cover;
# 							-webkit-background-size:cover;
# 							-moz-background-size:cover;
# 							-o-background-size:cover;
#
# 			border-color: #dddddd;		border-style: solid;
# 		width: 400px;
# 		margin: 0 auto;
# 		border-width: 1px;
#
#
# 	height: 20127px;
#
# 	}
#
# @media only screen and (max-width: 770px) {
# 	.border-holder {
# 		background-attachment: scroll !important;
# 	}
# }
#
# #page-block-itl8a5r5j7adobt9 .color-overlay
# {
# 			display: none;
# 	}
#
# 	#page-block-itl8a5r5j7adobt9 .block-inner
# 	{
# 		margin-top: -1px;
# 		height: calc(100% + 2px);
# 					margin-left: -1px;
# 			}
#
# #page-block-q6nkvc1zwsbawcdi { height: 50px; }
# #page-block-q6nkvc1zwsbawcdi .border-holder
# {
# 			background-image: none;
#
# 			background-color: #bbdbe5;
#
# 	background-repeat: repeat;						background-position: top left;
#
# 										background-size:cover;
# 							-webkit-background-size:cover;
# 							-moz-background-size:cover;
# 							-o-background-size:cover;
#
#
# 		width: 400px;
# 		margin: 0 auto;
# 		border-width: 0px;
#
#
# 	height: 50px;
#
# 	}
#
# @media only screen and (max-width: 770px) {
# 	.border-holder {
# 		background-attachment: scroll !important;
# 	}
# }
#
# #page-block-q6nkvc1zwsbawcdi .color-overlay
# {
# 			display: none;
# 	}
#
# 	#page-block-q6nkvc1zwsbawcdi .block-inner
# 	{
# 		margin-top: 0px;
# 		height: calc(100% + 0px);
# 					margin-left: 0px;
# 			}
# 						}
#
# @media
# screen and (min-width: 621px)  and (-webkit-max-device-pixel-ratio: 1.5),
# screen and (min-width: 1000px) and (-webkit-max-device-pixel-ratio: 1.5)
# {
# 	.new_mobile .page.page2.mobile .block-inner
# 	{
# 		width: 960px;
# 	}
# }
#   </style>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/sortable/0.6.0/css/sortable-theme-bootstrap.css" rel="stylesheet"/>
#   <script data-enforce-business-email="false" data-redirect-signup="false" data-tag="instapage-unicorns-tag" src="/js/instapage.min.js" type="text/javascript">
#   </script>
#   <!-- No GA Tracking code -->
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 				new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 				j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 				'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 				})(window,document,'script','dataLayer','GTM-MS68MJS' );
#   </script>
#   <!-- End Google Tag Manager -->
#  </head>
#  <body class=" new_mobile">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MS68MJS" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div class="page page2 " id="i-page">
#    <div class="notification">
#     <div class="notification-overlay">
#     </div>
#     <div class="notification-inner">
#      <img alt="" class="loading notification-loader" rel="//v.fastcdn.co/a/img/loading_circle.svg" src=""/>
#      <span class="message">
#      </span>
#      <span class="close-button" onclick="jQuery(this).parent().parent().hide()">
#       Close
#      </span>
#     </div>
#    </div>
#    <div class="page-block" id="page-block-0e0wkiaq9yk">
#     <div class="color-overlay">
#     </div>
#     <div class="border-holder">
#      <div class="block-inner">
#      </div>
#     </div>
#    </div>
#    <div class="page-block" id="page-block-m5ywl8e5c23xr">
#     <div class="color-overlay">
#     </div>
#     <div class="border-holder">
#      <div class="block-inner">
#       <div class="page-element widget-container page-element-type-image widget-image " id="element-1300">
#        <div class="contents">
#         <img alt="" src="//v.fastcdn.co/t/11443291/8d957988/1538411581-21739606-290x78-CBI-Logo-Color-5.png" style="margin-top: 0px;"/>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="page-block" id="page-block-20h8hausjmsiqkt9">
#     <div class="color-overlay">
#     </div>
#     <div class="border-holder">
#      <div class="block-inner">
#       <div class="page-element widget-container page-element-type-headline widget-headline " id="element-1292">
#        <div class="contents">
#         <h1>
#         </h1>
#         <p style=" ">
#          <font color="#003366">
#           The Global Unicorn Club
#          </font>
#         </p>
#        </div>
#       </div>
#       <div class="page-element widget-container page-element-type-text widget-text " id="element-1291">
#        <div class="contents">
#         <p style="text-align: left;  ">
#          <font color="#003366">
#           (including whisper valuations)
#          </font>
#         </p>
#        </div>
#       </div>
#       <div class="page-element widget-container page-element-type-text widget-text " id="element-1293">
#        <div class="contents">
#         <p style=" ">
#          <font color="#003366">
#           Current Private Companies Valued At $1B+
#          </font>
#         </p>
#         <p style=" ">
#          <font color="#003366">
#           <br/>
#          </font>
#         </p>
#         <p style=" ">
#          <font color="#003366">
#           <br/>
#          </font>
#         </p>
#         <p style=" ">
#          <font color="#003366">
#           Total Number of Unicorn Companies:
#          </font>
#          <font color="#ff6633">
#           277
#          </font>
#         </p>
#         <p style=" ">
#          <font color="#003366">
#           Total Cumulative Valuation:
#          </font>
#          <font color="#ff6633">
#           ~ $865B
#          </font>
#         </p>
#        </div>
#       </div>
#       <div class="page-element widget-container page-element-type-image widget-image " id="element-1294">
#        <div class="contents">
#         <img alt="" src="//v.fastcdn.co/t/11443291/8d957988/1538411580-23265466-215x238x215x241x0x3-Unicorn.png" style="margin-top: ;"/>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="page-block" id="page-block-qcm8zm0lvk">
#     <div class="color-overlay">
#     </div>
#     <div class="border-holder">
#      <div class="block-inner">
#       <div class="page-element widget-container page-element-type-form widget-form " id="element-18">
#        <style type="text/css">
#         #element-18 .submit-button
# 	{
# 		background-color: #ff6633;
#
# 					color: #ffffff;
#
#
# 			}
#
# 	#element-18 .submit-button:active
# 	{
# 			}
#
# 	#element-18 .field-checkbox .field-element input[type=checkbox]:checked + label:before
# 	{
# 		background-color: #ff6633;
# 		border-color: #ff6633;
# 	}
#
# 	#element-18 .field-radio .field-element label:after
# 	{
# 		border-color: #ff6633;
# 	}
#
# 	#element-18 .input-holder label
# 	{
# 		color: #000000;
# 	}
#
# 	#element-18 ::-webkit-input-placeholder
# 	{ /* WebKit browsers */
# 		color: #000000	}
#
# 	#element-18 :-moz-placeholder
# 	{ /* Mozilla Firefox 4 to 18 */
# 		color: #000000;
# 	}
#
# 	#element-18 ::-moz-placeholder
# 	{ /* Mozilla Firefox 19+ */
# 		color: #000000;
# 	}
#
# 	#element-18 :-ms-input-placeholder
# 	{ /* Internet Explorer 10+ */
# 		color: #000000;
# 	}
#
# 	#element-18 label.error
# 	{
# 		color: #C00;
# 	}
#
# 	#element-18 input[type="text"],
# 	#element-18 input[type="password"],
# 	#element-18 input[type="email"],
# 	#element-18 textarea
# 	{
# 		color: #000000;
# 					background-color: #ffffff;
#
# 					border-color: #555555;
# 			}
#
# 	#element-18 input::-webkit-input-placeholder
# 	{
# 		color: #000000;
# 	}
#
# 	#element-18 input:-moz-placeholder
# 	{
# 		color: #000000;
# 		opacity: 1;
# 	}
#
# 	#element-18 input::-moz-placeholder
# 	{
# 		color: #000000;
# 		opacity: 1;
# 	}
#
# 	#element-18 input:-ms-input-placeholder
# 	{
# 		color: #000000;
# 	}
#
# 			#element-18 select
# 		{
# 			color: #000000		}
#
# 	#element-18 select[label-position="inside"].pristine
# 	{
# 		color: #000000	}
#
# 			#element-18 select option
# 		{
# 							background-color: #ffffff;
# 					}
#
# 	#element-18 select
# 	{
# 					border-color: #555555;
# 							background-color: #ffffff;
# 			}
#
# 			#element-18 .dynamic-button:hover
# 		{
# 			background-color: #ff6633;
# 		}
#
# 					#element-18 .submit-holder
# 		{
# 			position: relative;
# 		}
#
# 		#element-18 .dynamic-button, #element-18 .image-button
# 		{
# 			position: absolute;
# 			margin: 0;
#
# 			top: 8px;
# 			left: 523px;
# 			width: 218px;
# 			height: 41px;
# 			box-sizing: content-box;
# 			line-height: 16px;
# 			font-size: 15px;
# 			font-weight: 700;
# 							font-family: Roboto;
# 										border-radius: 5px;					}
#
# 								@media
# 			screen and ( max-width: 620px ),
# 			screen and ( max-width: 999px ) and ( -webkit-min-device-pixel-ratio: 1.5 ) and ( max-device-width: 1280px ) and ( max-device-height: 720px ),
# 			screen and ( max-width: 999px ) and ( -webkit-min-device-pixel-ratio: 1.5 ) and ( max-device-width: 1000px )
# 			{
# 				body:not( .tablet ) #page-block-qcm8zm0lvk #element-18 .dynamic-button, body:not( .tablet ) #page-block-qcm8zm0lvk #element-18 .image-button
# 				{
# 					position: absolute;
# 					/* 243*/
# 					top: 96px;
# 					left: -1px;
# 					width: 358px;
# 					height: 68px;
# 					line-height: 27px;
# 					font-size: 23px;
# 				}
# 			}
#        </style>
#        <div class="widget-container widget-form" id="element-18">
#         <div class="contents">
#          <form action="https://d.fastcdn.co/submissions" class="email-form" data="instapage-form" data-wid="18" method="post">
#           <input name="variant" type="hidden" value="A"/>
#           <div class="input-holder field-text">
#            <div class="field-element ">
#             <input class="shortnice form-input required " data-label-inside="Enter your business email" id="92f0d7c2fdd933f375e6432a71724b99-0" name="RW50ZXIgeW91ciBidXNpbmVzcyBlbWFpbA==" placeholder="Enter your business email" type="email" value=""/>
#            </div>
#           </div>
#           <input class="configuration" name="redirect" type="hidden" value="http://www.cbinsights.com/research-thank-you-report-download"/>
#           <input class="configuration" name="webhook-integration" type="hidden" value="..."/>
#           <input class="configuration" name="Page Shown" type="hidden" value="Unicorns"/>
#           <input class="configuration" name="Variation Shown" type="hidden" value="A"/>
#           <input class="configuration" name="Desktop/Mobile" type="hidden" value=""/>
#           <input class="configuration" name="Timestamp" type="hidden" value=""/>
#           <input class="configuration" name="IP Address" type="hidden" value=""/>
#           <input class="configuration" name="Referral Source" type="hidden" value=""/>
#           <button class="btn submit-button button_submit dynamic-button corners ">
#            DOWNLOAD NOW
#           </button>
#           <input name="validation" type="hidden" value="Tzo4OiJzdGRDbGFzcyI6Mjp7czo2OiJmaWVsZHMiO2E6MTp7czoyNToiRW50ZXIgeW91ciBidXNpbmVzcyBlbWFpbCI7Tzo4OiJzdGRDbGFzcyI6MTp7czo4OiJyZXF1aXJlZCI7YjoxO319czo3OiJmb3JtX2lkIjtzOjMyOiI5MmYwZDdjMmZkZDkzM2YzNzVlNjQzMmE3MTcyNGI5OSI7fQ=="/>
#           <input name="lpsSubmissionConfig" type="hidden" value="eyJhbGciOiJIUzI1NiJ9.....K4DFcW9EhfzyM0ddErOp3OgmDqC0BnqrU32F8FxJff8"/>
#          </form>
#         </div>
#         <div style="clear: both">
#         </div>
#        </div>
#       </div>
#       <div class="page-element widget-container page-element-type-text widget-text " id="element-1304">
#        <div class="contents">
#         <p style="text-align: center;  ">
#         </p>
#         <p style="text-align: center;  ">
#          <font color="#ffffff">
#           <b>
#            DOWNLOAD THE FULL LIST OF BILLION DOLLAR COMPANIES TO SEE THEIR FUNDING DATA, INVESTORS, AND MORE
#           </b>
#          </font>
#         </p>
#         <p style="text-align: center;  ">
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="page-block" id="page-block-itl8a5r5j7adobt9">
#     <div class="color-overlay">
#     </div>
#     <div class="border-holder">
#      <div class="block-inner">
#       <div class="page-element widget-container page-element-type-html widget-html " id="element-32">
#        <div class="contents">
#         <table class="sortable-theme-bootstrap" data-sortable="">
#          <thead>
#           <tr>
#            <th>
#             Company
#            </th>
#            <th data-sorted="true" width="120">
#             Valuation ($B)
#            </th>
#            <th>
#             Date Joined
#            </th>
#            <th>
#             Country
#            </th>
#            <th>
#             Industry
#            </th>
#            <th data-sortable="false">
#             Select Investors
#            </th>
#           </tr>
#          </thead>
#          <tbody>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/uber">
#              Uber
#             </a>
#            </td>
#            <td data-value="72">
#             $72
#            </td>
#            <td>
#             8/23/2013
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             On-Demand
#            </td>
#            <td>
#             Lowercase Capital,
# 	  Benchmark Capital, Google Ventures
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/didi-kuaidi">
#              Didi Chuxing
#             </a>
#            </td>
#            <td data-value="56">
#             $56
#            </td>
#            <td>
#             12/31/2014
#            </td>
#            <td>
#             China
#            </td>
#            <td>
#             On-Demand
#            </td>
#            <td>
#             Matrix Partners, Tiger
# 	  Global Management, Softbank Corp.,
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/airbnb">
#              Airbnb
#             </a>
#            </td>
#            <td data-value="29.3">
#             $29.3
#            </td>
#            <td>
#             7/26/2011
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             eCommerce/Marketplace
#            </td>
#            <td>
#             General Catalyst Partners,
# 	  Andreessen Horowitz, ENIAC Ventures
#            </td>
#           </tr>
#           <tr>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/space-exploration-technologies">
#              SpaceX
#             </a>
#            </td>
#            <td data-value="21.5">
#             $21.5
#            </td>
#            <td>
#             12/1/2012
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             Other Transportation
#            </td>
#            <td>
#             Founders Fund, Draper
# 	  Fisher Jurvetson, Rothenberg Ventures
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/palantir-technologies">
#              Palantir
# 	  Technologies
#             </a>
#            </td>
#            <td data-value="20">
#             $20
#            </td>
#            <td>
#             5/5/2011
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             Big Data
#            </td>
#            <td>
#             RRE Ventures, Founders
# 	  Fund, In-Q-Tel
#            </td>
#           </tr>
#           <tr>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/wework">
#              WeWork
#             </a>
#            </td>
#            <td data-value="20">
#             $20
#            </td>
#            <td>
#             2/3/2014
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             Facilities
#            </td>
#            <td>
#             T. Rowe Price, Benchmark
# 	  Capital, SoftBank Group
#            </td>
#           </tr>
#           <td>
#            <a href="https://www.cbinsights.com/company/bytedance">
#             Toutiao (Bytedance)
#            </a>
#           </td>
#           <td data-value="20">
#            $20
#           </td>
#           <td>
#            4/7/2017
#           </td>
#           <td>
#            China
#           </td>
#           <td>
#            Digital Media/ AI
#           </td>
#           <td>
#            Sequoia Capital China, SIG Asia Investments, Sina Weibo
#           </td>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/stripe">
#              Stripe
#             </a>
#            </td>
#            <td data-value="20">
#             $20
#            </td>
#            <td>
#             1/23/2014
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             Fintech
#            </td>
#            <td>
#             Khosla Ventures, Lowercase
# 	  Capital, capitalG
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/shanghai-lujiazui-international-financial-asset-exchange-co">
#              Lu.com
#             </a>
#            </td>
#            <td data-value="18.5">
#             $18.5
#            </td>
#            <td>
#             12/26/2014
#            </td>
#            <td>
#             China
#            </td>
#            <td>
#             Fintech
#            </td>
#            <td>
#             Ping An Insurance CDH Investments, Bank of China
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/juul-labs">
#              JUUL Labs
#             </a>
#            </td>
#            <td data-value="15">
#             $15
#            </td>
#            <td>
#             12/20/2017
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             Consumer Electronics
#            </td>
#            <td>
#             Tiger Global Management
#            </td>
#           </tr>
#           <tr>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/pinterest">
#              Pinterest
#             </a>
#            </td>
#            <td data-value="12.3">
#             $12.3
#            </td>
#            <td>
#             5/19/2012
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             Social
#            </td>
#            <td>
#             Andreessen Horowitz, Bessemer Venture Partners, Firstmark Capital
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/bitmain-technologies">
#              Bitmain Technologies
#             </a>
#            </td>
#            <td data-value="12">
#             $12
#            </td>
#            <td>
#             7/6/2018
#            </td>
#            <td>
#             China
#            </td>
#            <td>
#             Blockchain
#            </td>
#            <td>
#             Coatue Management, Sequoia Capital China, IDG Capital
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/lyft">
#              Lyft
#             </a>
#            </td>
#            <td data-value="11.5">
#             $11.5
#            </td>
#            <td>
#             3/12/2015
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             On-Demand
#            </td>
#            <td>
#             Founders Fund, Mayfield
# 	  Fund, capitalG
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/grabtaxi">
#              GrabTaxi
#             </a>
#            </td>
#            <td data-value="11">
#             $11
#            </td>
#            <td>
#             12/4/2014
#            </td>
#            <td>
#             Singapore
#            </td>
#            <td>
#             On-Demand
#            </td>
#            <td>
#             GGV Capital, Vertex Venture
# 	  Holdings, Softbank Group
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/global-switch">
#              Global Switch
#             </a>
#            </td>
#            <td data-value="11.08">
#             $11.08
#            </td>
#            <td>
#             12/22/2016
#            </td>
#            <td>
#             United Kingdom
#            </td>
#            <td>
#             Computer Hardware &amp; Services
#            </td>
#            <td>
#             Aviation Industry Corporation of China, Essence Financial, Jiangsu Sha Steel Group
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/infor">
#              Infor
#             </a>
#            </td>
#            <td data-value="10">
#             $10
#            </td>
#            <td>
#             11/16/2016
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             Internet Software &amp; Services
#            </td>
#            <td>
#             Blackstone Group, Koch Industries
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/dji">
#              DJI
# 	  Innovations
#             </a>
#            </td>
#            <td data-value="10">
#             $10
#            </td>
#            <td>
#             5/6/2015
#            </td>
#            <td>
#             China
#            </td>
#            <td>
#             Hardware
#            </td>
#            <td>
#             Accel Partners, Sequoia
# 	  Capital
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/one97-communications">
#              One97
# 	  Communications (operates Paytm)
#             </a>
#            </td>
#            <td data-value="10">
#             $10
#            </td>
#            <td>
#             5/12/2015
#            </td>
#            <td>
#             India
#            </td>
#            <td>
#             Fintech
#            </td>
#            <td>
#             Intel Capital, Sapphire
# 	  Ventures, Alibaba Group
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/slack">
#              Slack
# 	  Technologies
#             </a>
#            </td>
#            <td data-value="7.1">
#             $7.1
#            </td>
#            <td>
#             10/31/2014
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             Internet Software &amp; Services
#            </td>
#            <td>
#             Google Ventures, Institutional Venture Partners, Index Ventures
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/snapdeal">
#              Snapdeal
#             </a>
#            </td>
#            <td data-value="7">
#             $7
#            </td>
#            <td>
#             5/21/2014
#            </td>
#            <td>
#             India
#            </td>
#            <td>
#             eCommerce/Marketplace
#            </td>
#            <td>
#             SoftBankGroup,Blackrock, Alibaba Group
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/beijing-homelink-real-estate-brokerage-co">
#              Lianjia (Homelink)
#             </a>
#            </td>
#            <td data-value="5.8">
#             $5.8
#            </td>
#            <td>
#             4/8/2016
#            </td>
#            <td>
#             China
#            </td>
#            <td>
#             eCommerce/Marketplace
#            </td>
#            <td>
#             Tencent, Baidu, Huasheng Capital
#            </td>
#           </tr>
#           <tr>
#            <td>
# ...
#            <td data-value="1">
#             $1
#            </td>
#            <td>
#             11/16/2017
#            </td>
#            <td>
#             Indonesia
#            </td>
#            <td>
#             eCommerce
#            </td>
#            <td>
#             500 Startups, Batavia Incubator, Emtek Group
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/root-insurance">
#              Root Insurance
#             </a>
#            </td>
#            <td data-value="1">
#             $1
#            </td>
#            <td>
#             8/22/2018
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             InsurTech
#            </td>
#            <td>
#             Tiger Global Management, Ribbit Capital, Redpoint Ventures
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/cohesity">
#              Cohesity
#             </a>
#            </td>
#            <td data-value="1">
#             $1
#            </td>
#            <td>
#             6/11/2018
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             Data Storage
#            </td>
#            <td>
#             SoftBank Group, Sequoia Capital, Wing Venture Capital
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/shansong-express">
#              Shansong Express (FlashEx)
#             </a>
#            </td>
#            <td data-value="1">
#             $1
#            </td>
#            <td>
#             8/27/2018
#            </td>
#            <td>
#             China
#            </td>
#            <td>
#             Supply Chain &amp; Logistics
#            </td>
#            <td>
#             Prometheus Capital, Matrix Partners China, JD Capital Management
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/byjus">
#              BYJU'S
#             </a>
#            </td>
#            <td data-value="1">
#             $1
#            </td>
#            <td>
#             8/27/2018
#            </td>
#            <td>
#             India
#            </td>
#            <td>
#             Ed Tech
#            </td>
#            <td>
#             Tencent Holdings, Lightsepeed India Partners, Sequoia Capital India
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/udaan">
#              Udaan
#             </a>
#            </td>
#            <td data-value="1">
#             $1
#            </td>
#            <td>
#             9/3/2018
#            </td>
#            <td>
#             India
#            </td>
#            <td>
#             e-commerce
#            </td>
#            <td>
#             DST Global, Lightspeed Venture Partners, Microsoft ScaleUp
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/Rappi">
#              Rappi
#             </a>
#            </td>
#            <td data-value="1">
#             $1
#            </td>
#            <td>
#             8/31/2018
#            </td>
#            <td>
#             Colombia
#            </td>
#            <td>
#             On-demand
#            </td>
#            <td>
#             DST Global, Andreessen Horowitz, Sequoia Capital, Redpoint e.ventures
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/xinyang-technology">
#              Xinyang Technology (SoYoung)
#             </a>
#            </td>
#            <td data-value="1">
#             $1
#            </td>
#            <td>
#             9/4/2018
#            </td>
#            <td>
#             China
#            </td>
#            <td>
#             e-commerce
#            </td>
#            <td>
#             Orchid Asia Group Management, Russia-China Investment Fund, Matrix Partners China
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/roblox">
#              Roblox
#             </a>
#            </td>
#            <td data-value="1">
#             $1
#            </td>
#            <td>
#             9/4/2018
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             Gaming
#            </td>
#            <td>
#             Atlos Ventures, Index Ventures, First Round Capital
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/aijia-life">
#              Aijia Life
#             </a>
#            </td>
#            <td data-value="1">
#             $1
#            </td>
#            <td>
#             9/17/2018
#            </td>
#            <td>
#             China
#            </td>
#            <td>
#             Construction Tech
#            </td>
#            <td>
#             Tiantu Capital, Fortune Capital, Zhenghedao Fund
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/nxin">
#              Nxin (农信互联)
#             </a>
#            </td>
#            <td data-value="1">
#             $1
#            </td>
#            <td>
#             9/18/2018
#            </td>
#            <td>
#             China
#            </td>
#            <td>
#             Ag Tech
#            </td>
#            <td>
#             Beijing Juneng Hesheng Industry Investment Fund, Beijing Shuju Xinrong Fund
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/walkme">
#              WalkMe
#             </a>
#            </td>
#            <td data-value="1">
#             $1
#            </td>
#            <td>
#             9/20/2018
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             Sales Tech
#            </td>
#            <td>
#             Gemini Israel Ventures, Insight Venture Partners, Giza Venture Capital
#            </td>
#           </tr>
#           <tr>
#            <td>
#             <a href="https://www.cbinsights.com/company/convoy">
#              Convoy
#             </a>
#            </td>
#            <td data-value="1">
#             $1
#            </td>
#            <td>
#             9/21/2018
#            </td>
#            <td>
#             United States
#            </td>
#            <td>
#             Supply Chain
#            </td>
#            <td>
#             Greylock Partners, capitalG, Y Combinator
#            </td>
#           </tr>
#          </tbody>
#         </table>
#        </div>
#       </div>
#       <div class="page-element widget-container page-element-type-headline widget-headline " id="element-1305">
#        <div class="contents">
#         <h2>
#         </h2>
#         <p style=" ">
#          <font color="#003366">
#           What is a Unicorn Startup?
#          </font>
#         </p>
#        </div>
#       </div>
#       <div class="page-element widget-container page-element-type-text widget-text " id="element-1306">
#        <div class="contents">
#         <p style=" ">
#          A unicorn startup or unicorn company is a private company with a valuation over $1 billion. As of August 2018, there are more than 260 unicorns around the world. Variants include a decacorn, valued at over $10 billion, and a hectocorn, valued at over $100 billion.
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="page-block" id="page-block-q6nkvc1zwsbawcdi">
#     <div class="color-overlay">
#     </div>
#     <div class="border-holder">
#      <div class="block-inner">
#       <div class="page-element widget-container page-element-type-text widget-text " id="element-16">
#        <div class="contents">
#         <p style="text-align: right;  ">
#          <font color="#003366">
#           ©2018 CB Insights, All Rights Reserved
#          </font>
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!-- No ReCaptcha enabled -->
#   <div id="fb-root">
#   </div>
#   <!-- visitor pixel -->
#   <script class="instapage-noscrap" type="text/javascript">
#    window.__conversions_settings = {"forms":true,"links":false,"external":false};
#
# 	function iCopyKeenEvent( name, properties )
# 	{
# 		var params_copy = window.__keen_io_called_parameters.slice();
# 		var data = {};
# 		properties = properties || {};
#
# 		for( i in params_copy[ 2 ] )
# 		{
# 			if( params_copy[ 2 ].hasOwnProperty( i ) )
# 			{
# 				data[ i ] = params_copy[ 2 ][ i ];
# 			}
# 		}
#
# 		for( i in properties )
# 		{
# 			if( properties.hasOwnProperty( i ) )
# 			{
# 				data[ i ] = properties[ i ];
# 			}
# 		}
#
# 		if( name === 'conversion' && window.__unique )
# 		{
# 			if( window.__unique.isVisited() )
# 			{
# 				data[ 'responsive_mode' ] = window.__unique.isResponsiveMode() ? 'mobile' : null;
# 			}
# 		}
#
#
# 		params_copy.splice( 1, 2, name, data );
# 		return params_copy;
# 	}
#
# 	function removeKeenEventParameter( name )
# 	{
# 		if( window.__keen_io_called_parameters ) {
# 			var parameters = window.__keen_io_called_parameters[2] ? window.__keen_io_called_parameters[2] : {};
#
# 			if( parameters[name] )
# 			{
# 				delete parameters[name];
# 				window.__keen_io_called_parameters[2] = parameters;
# 			}
# 		}
# 	}
#
# 	function iEncodePixelUrl( id, event, data, key )
# 	{
# 		var endpoint = "anthill.instapage.com" + '/projects/' + id + '/events/' + event;
# 		var base64 = window.base64_encode( JSON.stringify( data ) );
# 		var base64_url_safe = base64.replace(/\+/g, '-').replace(/\//g, '_');
# 		var query = 'api_key=' + key + '&data=' + base64_url_safe + '&t=' + Date.now();
# 		var image_url = '//' + endpoint + '?' + query;
#
# 		return image_url;
# 	}
#
# 	function iCreateTrackingPixel( src )
# 	{
# 		return ijQuery( '<img>')
# 			.attr( {
# 				src: src,
# 				width: 1,
# 				height: 1,
# 				alt: '',
# 				title: '',
# 				style: 'display: table-cell; height: 0; position: absolute; left: -9999999px; top: -999999px;'
# 			} )
# 	}
#
# 	ijQuery( document ).on( 'ready', function()
# 	{
# 		var cookie_name = 'instapage-visit-333259';
# 		var parameters = {"owner_id":100925,"customer_id":119007,"user_id":100925,"page_id":333259,"published_version":1163,"quantity":1,"static_page":false,"variation_name":"A","variation_id":1,"linked_variation_id":2,"initial_responsive_mode":null,"visitor_ip":"35.202.96.207","useragent":""};
# 		var id = '333259';
# 		var track_returning_visitors = true;
#
# 		var project_id = '56c2f3d796773d0a7e96a536';
# 		var event = 'visit';
# 		var key = '';
#
# 		parameters.javascript = true;
# 		parameters.variation = parameters.variation_name;
# 		parameters.generation_time = '5';
# 		parameters.responsive_mode = null;
#
# 		if( window.__mobile_version === 2 && window.innerWidth < 600 && window.__variant.indexOf( '-mobile' ) < 0 )
# 		{
# 			window.__variant += '-mobile';
# 			parameters.responsive_mode = 'mobile';
# 		}
# 		else if( window.__variant.indexOf( '-mobile' ) > 0 )
# 		{
# 			parameters.responsive_mode = 'mobile';
# 		}
#
# 		window.__unique = new InstapageUniqueVisit( cookie_name, {
# 			variant: parameters.variation_name,
# 			responsive_mode: parameters.responsive_mode,
# 			reset: {}		} );
#
# 		parameters.visited = window.__unique.isVisited();
# 		parameters.useragent = window.navigator && window.navigator.userAgent || parameters.useragent;
#
# 		parameters.campaign_id = window.__unique.getCampaignId();
# 		parameters.ad_id = window.__unique.getAdId();
# 		parameters.campaign_source = window.__unique.getCampaignSource();
#
# 		parameters.ref = window.__unique.getRef();
#
# 		window.__keen_io_called_parameters = [ project_id, event, parameters, key ];
# 		if( !parameters.visited || track_returning_visitors )
# 		{
# 			iCreateTrackingPixel( iEncodePixelUrl( project_id, event, parameters, key ) )
# 				.appendTo( ijQuery( 'body' ) );
#
# 			window.__unique.setResponsiveMode( parameters.responsive_mode );
# 			window.__unique.setVisited();
# 			window.__unique.save();
#
# 			//Remove ad_id parameter for multiple submit protection
# 			removeKeenEventParameter( 'ad_id' );
# 		}
#
# 		if( window.__conversions_settings.external && typeof $.cookie( 'instapage.conversion' + id ) === 'undefined' )
# 		{
# 			var parameter_pixel = iCopyKeenEvent( "conversion", {
# 				conversion_type: "external",
# 				visited: window.__unique.isConverted()
# 			} );
# 			var external_image = iEncodePixelUrl.apply( iEncodePixelUrl, parameter_pixel );
#
# 			var data = {
# 				page_id: id,
# 				variation: parameters.variation_name,
# 				external_image: external_image,
# 				timestamp_created: Date.now(),
# 				timestamp_sent: null
# 			};
#
# 			$.cookie( 'instapage.conversion' + id, JSON.stringify( data ), {
# 				expires: 7,
# 				path: '/'
# 			} );
# 		}
# 	} );
#   </script>
#   <noscript class="instapage-noscrap">
#    <img href="//anthill.instapage.com/projects/56c2f3d796773d0a7e96a536/events/visit?api_key=&amp;data="/>
#   </noscript>
#   <!-- end -->
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/sortable/0.6.0/js/sortable.min.js">
#   </script>
#   <iframe class="instapage-noscrap" height="0px" name="instapage-local-storage" src="//d3mwhxgzltpnyp.cloudfront.net/local-storage/index.html" style="display: block;" width="0px">
#   </iframe>
#   <script>
#    function getWidgetsHorizontalBoundries()
# 			{
# 					var $body;
# 					var page_width;
# 					var edges = { left: 0, right: 0 };
#
# 					$body = ijQuery( 'html, body' );
# 					page_width = ijQuery( '.block-inner' ).first().width();
#
# 					ijQuery( '.page-element:visible' ).each( function( index, elem )
# 					{
# 							var $elem = ijQuery( elem );
# 							var left = $elem.position().left;
# 							var width = $elem.width();
# 							var right = left + width;
# 							if ( left < 0 && edges.left > left )
# 							{
# 									edges.left = left;
# 							}
#
# 							if ( right > page_width && edges.right < right )
# 							{
# 									edges.right = right;
# 							}
# 					} );
#
# 					max = Math.max( Math.abs( edges.left ), edges.right - page_width );
# 					return page_width + max * 2;
# 			}
# 			window.__workspaceWidth = getWidgetsHorizontalBoundries();
#   </script>
#   <script>
#    ijQuery( document ).ready( function()
# 				{
# 					var $window = ijQuery( window );
# 					var last_window_width;
#
# 					function setupScroll()
# 					{
# 						var window_width = $window.width();
# 						var $body;
# 						var page_width;
# 						var edges = { left: 0, right: 0 };
# 						var max;
# 						var width;
# 						var scroll_left = 0;
#
# 						if ( last_window_width !== window_width )
# 						{
# 							$body = ijQuery( 'html, body' );
#
# 							if ( window.__workspaceWidth > window_width && window_width > 400 )
# 							{
# 								scroll_left = Math.round( ( window.__workspaceWidth - window_width ) / 2 );
# 								$body.css( 'min-width', window.__workspaceWidth + 'px' );
# 								ijQuery( 'html' ).css( 'overflow-x', 'visible' );
# 								$body.scrollLeft( scroll_left );
# 							}
# 							else
# 							{
# 								$body.css( 'min-width', '' );
# 								$body.scrollLeft( 0 );
# 								ijQuery( 'html' ).css( 'overflow-x', 'hidden' );
# 							}
#
# 							last_window_width = window_width;
# 						}
# 					}
#
# 					setupScroll();
#
# 					$window
# 						.off( 'resize.horizontalScrollHandler' )
# 						.on( 'resize.horizontalScrollHandler', setupScroll );
# 				} );
#   </script>
#   <script async="" src="https://heatmap.services/static/lib.js">
#   </script>
#  </body>
# </html>

# %%
"""Select data table content"""
table = soup.select('.sortable-theme-bootstrap')[0]

# %% [markdown]
# # Parsing Content Table Data

# %%
def parse_table(table):
    """ Get data from table """
    
    parsed = []
    for row in table.find_all("tr"):
        for cell in row.find_all(['td','th']):
            parsed.append(cell.get_text())
            
    header = parsed[:6]
    result = []
    
    """convert list mappings into dictionary """
    
    for row in [parsed[i:i + 6] for i in range(6, len(parsed), 6)]:
        temp ={}
        for n in range(6):
            ## data cleaning : remove extra characters /n/t, $symbol
            row[n] = re.sub('\s+', ' ', row[n])
            row[n] =row[n].replace("$", "")

            temp[header[n]]=row[n]
            
        result.append(temp)        
            
    return result

# %%
unicorn = parse_table(table)

# %%
unicorn
# Out:
# [{u'Company': u'Uber',
#   u'Country': u'United States',
#   u'Date Joined': u'8/23/2013',
#   u'Industry': u'On-Demand',
#   u'Select Investors': u'Lowercase Capital, Benchmark Capital, Google Ventures',
#   u'Valuation ($B)': u'72'},
#  {u'Company': u'Didi Chuxing ',
#   u'Country': u'China',
#   u'Date Joined': u'12/31/2014',
#   u'Industry': u'On-Demand',
#   u'Select Investors': u'Matrix Partners, Tiger Global Management, Softbank Corp.,',
#   u'Valuation ($B)': u'56'},
#  {u'Company': u'Airbnb',
#   u'Country': u'United States',
#   u'Date Joined': u'7/26/2011',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'General Catalyst Partners, Andreessen Horowitz, ENIAC Ventures',
#   u'Valuation ($B)': u'29.3'},
#  {u'Company': u'SpaceX',
#   u'Country': u'United States',
#   u'Date Joined': u'12/1/2012',
#   u'Industry': u'Other Transportation',
#   u'Select Investors': u'Founders Fund, Draper Fisher Jurvetson, Rothenberg Ventures',
#   u'Valuation ($B)': u'21.5'},
#  {u'Company': u'Palantir Technologies',
#   u'Country': u'United States',
#   u'Date Joined': u'5/5/2011',
#   u'Industry': u'Big Data',
#   u'Select Investors': u'RRE Ventures, Founders Fund, In-Q-Tel',
#   u'Valuation ($B)': u'20'},
#  {u'Company': u'WeWork',
#   u'Country': u'United States',
#   u'Date Joined': u'2/3/2014',
#   u'Industry': u'Facilities',
#   u'Select Investors': u'T. Rowe Price, Benchmark Capital, SoftBank Group',
#   u'Valuation ($B)': u'20'},
#  {u'Company': u'Stripe',
#   u'Country': u'United States',
#   u'Date Joined': u'1/23/2014',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Khosla Ventures, Lowercase Capital, capitalG',
#   u'Valuation ($B)': u'20'},
#  {u'Company': u'Lu.com',
#   u'Country': u'China',
#   u'Date Joined': u'12/26/2014',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Ping An Insurance CDH Investments, Bank of China',
#   u'Valuation ($B)': u'18.5'},
#  {u'Company': u'JUUL Labs',
#   u'Country': u'United States',
#   u'Date Joined': u'12/20/2017',
#   u'Industry': u'Consumer Electronics',
#   u'Select Investors': u'Tiger Global Management',
#   u'Valuation ($B)': u'15'},
#  {u'Company': u'Pinterest',
#   u'Country': u'United States',
#   u'Date Joined': u'5/19/2012',
#   u'Industry': u'Social',
#   u'Select Investors': u'Andreessen Horowitz, Bessemer Venture Partners, Firstmark Capital',
#   u'Valuation ($B)': u'12.3'},
#  {u'Company': u'Bitmain Technologies',
#   u'Country': u'China',
#   u'Date Joined': u'7/6/2018',
#   u'Industry': u'Blockchain',
#   u'Select Investors': u'Coatue Management, Sequoia Capital China, IDG Capital',
#   u'Valuation ($B)': u'12'},
#  {u'Company': u'Lyft',
#   u'Country': u'United States',
#   u'Date Joined': u'3/12/2015',
#   u'Industry': u'On-Demand',
#   u'Select Investors': u'Founders Fund, Mayfield Fund, capitalG',
#   u'Valuation ($B)': u'11.5'},
#  {u'Company': u'GrabTaxi',
#   u'Country': u'Singapore',
#   u'Date Joined': u'12/4/2014',
#   u'Industry': u'On-Demand',
#   u'Select Investors': u'GGV Capital, Vertex Venture Holdings, Softbank Group',
#   u'Valuation ($B)': u'11'},
#  {u'Company': u'Global Switch',
#   u'Country': u'United Kingdom',
#   u'Date Joined': u'12/22/2016',
#   u'Industry': u'Computer Hardware & Services',
#   u'Select Investors': u'Aviation Industry Corporation of China, Essence Financial, Jiangsu Sha Steel Group',
#   u'Valuation ($B)': u'11.08'},
#  {u'Company': u'Infor',
#   u'Country': u'United States',
#   u'Date Joined': u'11/16/2016',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Blackstone Group, Koch Industries',
#   u'Valuation ($B)': u'10'},
#  {u'Company': u'DJI Innovations',
#   u'Country': u'China',
#   u'Date Joined': u'5/6/2015',
#   u'Industry': u'Hardware',
#   u'Select Investors': u'Accel Partners, Sequoia Capital',
#   u'Valuation ($B)': u'10'},
#  {u'Company': u'One97 Communications (operates Paytm)',
#   u'Country': u'India',
#   u'Date Joined': u'5/12/2015',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Intel Capital, Sapphire Ventures, Alibaba Group',
#   u'Valuation ($B)': u'10'},
#  {u'Company': u'Slack Technologies',
#   u'Country': u'United States',
#   u'Date Joined': u'10/31/2014',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Google Ventures, Institutional Venture Partners, Index Ventures',
#   u'Valuation ($B)': u'7.1'},
#  {u'Company': u'Snapdeal',
#   u'Country': u'India',
#   u'Date Joined': u'5/21/2014',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'SoftBankGroup,Blackrock, Alibaba Group',
#   u'Valuation ($B)': u'7'},
#  {u'Company': u'Lianjia (Homelink)',
#   u'Country': u'China',
#   u'Date Joined': u'4/8/2016',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Tencent, Baidu, Huasheng Capital',
#   u'Valuation ($B)': u'5.8'},
#  {u'Company': u'Manbang Group',
#   u'Country': u'China',
#   u'Date Joined': u'4/24/2018',
#   u'Industry': u'Supply chain & Logistics',
#   u'Select Investors': u'Softbank Group, CapitalG',
#   u'Valuation ($B)': u'6'},
#  {u'Company': u'EasyHome',
#   u'Country': u'China',
#   u'Date Joined': u'2/12/2018',
#   u'Industry': u'Retail',
#   u'Select Investors': u'Alibaba Group, Boyu Capital, Borui Capital',
#   u'Valuation ($B)': u'5.7'},
#  {u'Company': u'Vice Media',
#   u'Country': u'United States',
#   u'Date Joined': u'8/17/2013',
#   u'Industry': u'Media',
#   u'Select Investors': u'Technology Crossover Ventures, A&E Television Networks',
#   u'Valuation ($B)': u'5.7'},
#  {u'Company': u'Robinhood',
#   u'Country': u'United States',
#   u'Date Joined': u'4/26/2017',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Google Ventures, Andreessen Horowitz, DST Global',
#   u'Valuation ($B)': u'5.6'},
#  {u'Company': u'Intarcia Therapeutics',
#   u'Country': u'United States',
#   u'Date Joined': u'4/1/2014',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'New Enterprise Associates, New Leaf Venture Partners, Charter Venture Capital',
#   u'Valuation ($B)': u'5.5'},
#  {u'Company': u'Outcome Health',
#   u'Country': u'United States',
#   u'Date Joined': u'5/31/2017',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'Goldman Sachs, capitalG, Pritzker Group Venture Capital',
#   u'Valuation ($B)': u'5'},
#  {u'Company': u'UBTECH Robotics',
#   u'Country': u'China',
#   u'Date Joined': u'7/26/2016',
#   u'Industry': u'Robotics',
#   u'Select Investors': u'CDH Investments, Goldstone Investments, Qiming Venture Partners',
#   u'Valuation ($B)': u'5'},
#  {u'Company': u'Tanium',
#   u'Country': u'United States',
#   u'Date Joined': u'3/31/2015',
#   u'Industry': u'Cybersecurity',
#   u'Select Investors': u'Andreessen Horowitz, Nor-Cal Invest, TPG Growth',
#   u'Valuation ($B)': u'5'},
#  {u'Company': u'Oyo Rooms',
#   u'Country': u'India',
#   u'Date Joined': u'9/25/2018',
#   u'Industry': u'Travel Tech',
#   u'Select Investors': u'SoftBank Group, Sequoia Capital India,Lightspeed India Partners',
#   u'Valuation ($B)': u'5'},
#  {u'Company': u'Magic Leap',
#   u'Country': u'United States',
#   u'Date Joined': u'10/21/2014',
#   u'Industry': u'VR/AR',
#   u'Select Investors': u'Obvious Ventures, Qualcomm Ventures, Andreessen Horowitz',
#   u'Valuation ($B)': u'4.98'},
#  {u'Company': u'Fanatics',
#   u'Country': u'United States',
#   u'Date Joined': u'6/6/2012',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'SoftBank Group, Andreessen Horowitz, Temasek Holdings',
#   u'Valuation ($B)': u'4.5'},
#  {u'Company': u'SenseTime',
#   u'Country': u'China',
#   u'Date Joined': u'7/11/2017',
#   u'Industry': u'Computer Vision/ AI',
#   u'Select Investors': u'Star VC, IDG Capital, Infore Capital, Alibaba Group',
#   u'Valuation ($B)': u'4.5'},
#  {u'Company': u'Social Finance (SoFi)',
#   u'Country': u'United States',
#   u'Date Joined': u'2/3/2015',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Baseline Ventures, DCM Ventures, Institutional Venture Partners',
#   u'Valuation ($B)': u'4.5'},
#  {u'Company': u'Faraday Future',
#   u'Country': u'United States',
#   u'Date Joined': u'4/19/2018',
#   u'Industry': u'AutoTech',
#   u'Select Investors': u'Evergrande Health Industry Group, Jia Yueting',
#   u'Valuation ($B)': u'4.4'},
#  {u'Company': u'Compass',
#   u'Country': u'United States',
#   u'Date Joined': u'8/31/2016',
#   u'Industry': u'Real Estate',
#   u'Select Investors': u'Founders Fund, Thrive Capital, Wellington Management',
#   u'Valuation ($B)': u'4.4'},
#  {u'Company': u'Instacart',
#   u'Country': u'United States',
#   u'Date Joined': u'12/30/2014',
#   u'Industry': u'On-Demand',
#   u'Select Investors': u'Khosla Ventures, Kleiner Perkins Caufield & Byers, Collaborative Fund',
#   u'Valuation ($B)': u'4.35'},
#  {u'Company': u'Olacabs',
#   u'Country': u'India',
#   u'Date Joined': u'10/27/2014',
#   u'Industry': u'On-demand',
#   u'Select Investors': u'Accel Partners, SoftBank Group, Sequoia Capital',
#   u'Valuation ($B)': u'4.3'},
#  {u'Company': u'Yello Mobile',
#   u'Country': u'South Korea',
#   u'Date Joined': u'11/11/2014',
#   u'Industry': u'Mobile Software & Services',
#   u'Select Investors': u'Formation 8',
#   u'Valuation ($B)': u'4'},
#  {u'Company': u'Houzz',
#   u'Country': u'United States',
#   u'Date Joined': u'9/30/2014',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'New Enterprise Associates, Sequoia Capital, Comcast Ventures',
#   u'Valuation ($B)': u'4'},
#  {u'Company': u'DoorDash',
#   u'Country': u'United States',
#   u'Date Joined': u'3/1/2018',
#   u'Industry': u'Food Delivery',
#   u'Select Investors': u'Softbank Group, Sequoia Capital, Khosla Ventures',
#   u'Valuation ($B)': u'4'},
#  {u'Company': u'XPeng Motors',
#   u'Country': u'China',
#   u'Date Joined': u'8/2/2018',
#   u'Industry': u'Automobile',
#   u'Select Investors': u'Morningside Venture Capital, Foxconn Technology Company, Alibaba Group',
#   u'Valuation ($B)': u'3.65'},
#  {u'Company': u'Auto1 Group',
#   u'Country': u'Germany',
#   u'Date Joined': u'8/3/2015',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Digital Sky Technologies, Piton Capital, DN Capital, SoftBank Group',
#   u'Valuation ($B)': u'3.54'},
#  {u'Company': u'Otto Bock HealthCare',
#   u'Country': u'Germany',
#   u'Date Joined': u'6/24/2017',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'EQT Partners',
#   u'Valuation ($B)': u'3.5'},
#  {u'Company': u'Credit Karma',
#   u'Country': u'United States',
#   u'Date Joined': u'9/29/2014',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Felicis Ventures, SV Angel, Founders Fund',
#   u'Valuation ($B)': u'3.5'},
#  {u'Company': u'Indigo Agriculture',
#   u'Country': u'United States',
#   u'Date Joined': u'9/26/2017',
#   u'Industry': u'Biotech',
#   u'Select Investors': u'Activant Capital Group, Alaska Permanent Fund, Baillie Gifford & Co.',
#   u'Valuation ($B)': u'3.5'},
#  {u'Company': u'Youxia Motors',
#   u'Country': u'China',
#   u'Date Joined': u'4/2/2018',
#   u'Industry': u'Automobile',
#   u'Select Investors': u'China Environmental Protection Industry, China Fortune Ocean',
#   u'Valuation ($B)': u'3.35'},
#  {u'Company': u'The Hut Group',
#   u'Country': u'United Kingdom',
#   u'Date Joined': u'08/13/2017',
#   u'Industry': u'eCommerce ',
#   u'Select Investors': u'Kohlberg Kravis Roberts & Co., Old Mutual Global Investors, Artemis Investment Management',
#   u'Valuation ($B)': u'3.25'},
#  {u'Company': u'Oscar Health Insurance Co.',
#   u'Country': u'United States',
#   u'Date Joined': u'4/20/2015',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'BoxGroup, Formation8, Khosla Ventures',
#   u'Valuation ($B)': u'3.2'},
#  {u'Company': u'Zoox',
#   u'Country': u'United States',
#   u'Date Joined': u'5/27/2016',
#   u'Industry': u'Auto Tech',
#   u'Select Investors': u'AID Partners, Draper Fisher Jurvetson',
#   u'Valuation ($B)': u'3.2'},
#  {u'Company': u'Kuaishou',
#   u'Country': u'China',
#   u'Date Joined': u'1/1/2015',
#   u'Industry': u'Social',
#   u'Select Investors': u'Morningside Venture Capital, Sequoia Capital, Baidu',
#   u'Valuation ($B)': u'3'},
#  {u'Company': u'VANCL',
#   u'Country': u'China',
#   u'Date Joined': u'12/14/2010',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Ceyuan Ventures, QiMing Venture Partners, Temasek Holdings',
#   u'Valuation ($B)': u'3'},
#  {u'Company': u'Moderna',
#   u'Country': u'United States',
#   u'Date Joined': u'12/19/2014',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'Flagship Ventures, Invus Group, Wellington Management',
#   u'Valuation ($B)': u'3'},
#  {u'Company': u'ContextLogic (dba. Wish)',
#   u'Country': u'United States',
#   u'Date Joined': u'5/18/2015',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Founders Fund, GGV Capital, Digital Sky Technologies',
#   u'Valuation ($B)': u'3'},
#  {u'Company': u'BGL Group',
#   u'Country': u'United Kingdom',
#   u'Date Joined': u'11/24/2017',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'CPP Investment Board',
#   u'Valuation ($B)': u'3'},
#  {u'Company': u'Circle Internet Financial',
#   u'Country': u'United States',
#   u'Date Joined': u'5/15/2018',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'General Catalyst, Digital Currency Group, Accel',
#   u'Valuation ($B)': u'3'},
#  {u'Company': u'Xiaohongshu',
#   u'Country': u'China',
#   u'Date Joined': u'3/31/2016',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'GGV Capital, ZhenFund, Tencent',
#   u'Valuation ($B)': u'3'},
#  {u'Company': u'Unity Technologies',
#   u'Country': u'United States',
#   u'Date Joined': u'7/13/2016',
#   u'Industry': u'Gaming',
#   u'Select Investors': u'Sequoia Capital, iGlobe Partners, DFJ Growth',
#   u'Valuation ($B)': u'3'},
#  {u'Company': u'CrowdStrike',
#   u'Country': u'United States',
#   u'Date Joined': u'5/17/2017',
#   u'Industry': u'Cybersecurity',
#   u'Select Investors': u'Warbug Pincus, capitalG, Accel Partners',
#   u'Valuation ($B)': u'3'},
#  {u'Company': u'Vipkid',
#   u'Country': u'China',
#   u'Date Joined': u'8/23/2017',
#   u'Industry': u'Edtech',
#   u'Select Investors': u'Sequoia Capital China, Tencent Holdings, Sinovation Ventures',
#   u'Valuation ($B)': u'3'},
#  {u'Company': u'SouChe Holdings',
#   u'Country': u'China',
#   u'Date Joined': u'11/1/2017',
#   u'Industry': u'AutoTech',
#   u'Select Investors': u'Morningside Ventures, Warburg Pincus, CreditEase Fintech Investment Fund',
#   u'Valuation ($B)': u'3'},
#  {u'Company': u'UiPath',
#   u'Country': u'United States',
#   u'Date Joined': u'3/2/2018',
#   u'Industry': u'Robotic Process Automation',
#   u'Select Investors': u'Accel Partners, capitalG, Earlybrid Venture Capital, Kleiner Perkins Caufield & Byers',
#   u'Valuation ($B)': u'3'},
#  {u'Company': u'Niantic',
#   u'Country': u'United States',
#   u'Date Joined': u'11/24/2017',
#   u'Industry': u'AR/VR',
#   u'Select Investors': u'Nintendo, Google, Pokemon Company International, Spark Capital',
#   u'Valuation ($B)': u'3'},
#  {u'Company': u' ESR Cayman (e-Shang Redwood)',
#   u'Country': u'China',
#   u'Date Joined': u'7/26/2017',
#   u'Industry': u'Real Estate',
#   u'Select Investors': u'SK Group, GF Investments, China Minsheng Banking Corp.',
#   u'Valuation ($B)': u'2.8'},
#  {u'Company': u'Meicai',
#   u'Country': u'China',
#   u'Date Joined': u'1/11/2018',
#   u'Industry': u'Food & Grocery',
#   u'Select Investors': u'Tiger Global Management, Blue Lake Capital, ZhenFund',
#   u'Valuation ($B)': u'2.8'},
#  {u'Company': u'Klarna',
#   u'Country': u'Sweden',
#   u'Date Joined': u'12/12/2011',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Institutional Venture Partners, Sequoia Capital, General Atlantic',
#   u'Valuation ($B)': u'2.5'},
#  {u'Company': u'VistaJet',
#   u'Country': u'Malta',
#   u'Date Joined': u'8/23/2017',
#   u'Industry': u'On-demand',
#   u'Select Investors': u'Rhone Capital',
#   u'Valuation ($B)': u'2.5'},
#  {u'Company': u'Qualtrics',
#   u'Country': u'United States',
#   u'Date Joined': u'9/24/2014',
#   u'Industry': u'Big Data',
#   u'Select Investors': u'Accel Partners, Insight Venture Partners, Sequoia Capital',
#   u'Valuation ($B)': u'2.5'},
#  {u'Company': u'Zhihu',
#   u'Country': u'China',
#   u'Date Joined': u'1/12/2017',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Tencent Holdings, Sinovation Ventures, Qiming Venture Partners ',
#   u'Valuation ($B)': u'2.5'},
#  {u'Company': u'GRAIL',
#   u'Country': u'United States',
#   u'Date Joined': u'3/1/2017',
#   u'Industry': u'Genomics',
#   u'Select Investors': u'Kleiner Perkins Caufield & Byers, Amazon, Merck & Co.',
#   u'Valuation ($B)': u'2.46'},
#  {u'Company': u'YITU Technology',
#   u'Country': u'China',
#   u'Date Joined': u'3/8/2018',
#   u'Industry': u'Computer Vision',
#   u'Select Investors': u'Sequoia Capital China, Banyan Capital',
#   u'Valuation ($B)': u'2.37'},
#  {u'Company': u'Uptake',
#   u'Country': u'United States',
#   u'Date Joined': u'10/27/2015',
#   u'Industry': u'Big Data',
#   u'Select Investors': u'Revolution, New Enterprise Associates, Caterpillar',
#   u'Valuation ($B)': u'2.3'},
#  {u'Company': u'ACORN OakNorth',
#   u'Country': u'United Kingdom',
#   u'Date Joined': u'10/12/2017',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Clermont Group, Coltrane Asset Management, Toscafund Asset Management',
#   u'Valuation ($B)': u'2.3'},
#  {u'Company': u'NuCom Group',
#   u'Country': u'Germany',
#   u'Date Joined': u'2/22/2018',
#   u'Industry': u'Management & Strategy Consulting',
#   u'Select Investors': u'General Atlantic',
#   u'Valuation ($B)': u'2.2'},
#  {u'Company': u'Babytree',
#   u'Country': u'United States',
#   u'Date Joined': u'5/28/2018',
#   u'Industry': u'Kids and Baby Tech',
#   u'Select Investors': u'Alibaba Group, Matric Partners China, Jumei International Holdings ',
#   u'Valuation ($B)': u'2.2'},
#  {u'Company': u'MINISO Life',
#   u'Country': u'China',
#   u'Date Joined': u'9/30/2018',
#   u'Industry': u'Retail',
#   u'Select Investors': u'Hillhouse Capital Management, and Tencent Holdings',
#   u'Valuation ($B)': u'2.2'},
#  {u'Company': u'ReNew Power Ventures',
#   u'Country': u'India',
#   u'Date Joined': u'2/14/2017',
#   u'Industry': u'Energy & Utilities',
#   u'Select Investors': u'Goldman Sachs, JERA, Asian Development Bank',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'Traveloka',
#   u'Country': u'Indonesia',
#   u'Date Joined': u'7/28/2017',
#   u'Industry': u'TravelTech',
#   u'Select Investors': u'Global Founders Capital, East Ventures, Expedia Inc.',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'Huimin',
#   u'Country': u'China',
#   u'Date Joined': u'9/5/2016',
#   u'Industry': u'On-Demand',
#   u'Select Investors': u'Zheshang Venture Capital, GP Capital, Western Capital Management',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'Avant',
#   u'Country': u'United States',
#   u'Date Joined': u'9/30/2015',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'RRE Ventures, Tiger Global, August Capital',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'Trendy Group International',
#   u'Country': u'China',
#   u'Date Joined': u'2/13/2012',
#   u'Industry': u'Clothing & Accessories',
#   u'Select Investors': u'L Capital Partners',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'Weiying',
#   u'Country': u'China',
#   u'Date Joined': u'11/17/2015',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Tencent, iDreamSky Technology, GGV Capital',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'Affirm',
#   u'Country': u'United States',
#   u'Date Joined': u'12/11/2017',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Andreessen Horowitz, Khosla Ventures, Singapore Wealth Fund',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'Nubank',
#   u'Country': u'Brazil',
#   u'Date Joined': u'3/1/2018',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Sequoia Capital, Redpoint e.ventures, Kaszek Ventures',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'Cambricon',
#   u'Country': u'China',
#   u'Date Joined': u'8/18/2017',
#   u'Industry': u'Chips & Semiconductors',
#   u'Select Investors': u'Alibaba Entrepreneurs Fund, CAS Investment Management Co., Lenovo Ventures Group',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'Preferred Networks',
#   u'Country': u'Japan',
#   u'Date Joined': u'5/17/2018',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Toyota Motor Corporation, Mizuho Financial Group, FANUC',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'Improbable',
#   u'Country': u'United Kingdom',
#   u'Date Joined': u'5/12/2017',
#   u'Industry': u'AR/VR',
#   u'Select Investors': u'Andreessen Horowitz, SoftBank Group, Temasek Holdings',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'LegalZoom',
#   u'Country': u'United States',
#   u'Date Joined': u'7/31/2018',
#   u'Industry': u'RegTech',
#   u'Select Investors': u'K1 Capital, Francisco Partners, Neuberger Berman',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'Tempus Labs',
#   u'Country': u'United States',
#   u'Date Joined': u'3/21/2018',
#   u'Industry': u'Robotic Process Automation',
#   u'Select Investors': u'New Enterprise Associates, T. Rowe Associates, Lightbank',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'OpenDoor Labs',
#   u'Country': u'United States',
#   u'Date Joined': u'11/30/2016',
#   u'Industry': u'Real Estate',
#   u'Select Investors': u'Norwest Venture Partners, New Enterprise Associates, Khosla Ventures',
#   u'Valuation ($B)': u'2'},
#  {u'Company': u'Quora',
#   u'Country': u'United States',
#   u'Date Joined': u'4/21/2017',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Y Combinator, Matrix Partners, Benchmark',
#   u'Valuation ($B)': u'1.8'},
#  {u'Company': u'Zocdoc',
#   u'Country': u'United States',
#   u'Date Joined': u'8/20/2015',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'Founders Fund, Khosla Ventures, Goldman Sachs',
#   u'Valuation ($B)': u'1.8'},
#  {u'Company': u'Sprinklr',
#   u'Country': u'United States',
#   u'Date Joined': u'3/31/2015',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Azure Capital Partners, Battery Ventures, Intel Capital',
#   u'Valuation ($B)': u'1.8'},
#  {u'Company': u'reddit',
#   u'Country': u'United States',
#   u'Date Joined': u'7/31/2017',
#   u'Industry': u'Social',
#   u'Select Investors': u'Y Combinator, Sequoia Capital, Coatue Management',
#   u'Valuation ($B)': u'1.8'},
#  {u'Company': u'Automation Anywhere',
#   u'Country': u'United States',
#   u'Date Joined': u'7/2/2018',
#   u'Industry': u'Robotics',
#   u'Select Investors': u'General Atlantic, Goldman Sachs, New Enterprise Associates',
#   u'Valuation ($B)': u'1.8'},
#  {u'Company': u'L&P Cosmetic',
#   u'Country': u'South Korea',
#   u'Date Joined': u'4/28/2017',
#   u'Industry': u'Beauty & grooming',
#   u'Select Investors': u'CDIB Capital',
#   u'Valuation ($B)': u'1.78'},
#  {u'Company': u'Apttus',
#   u'Country': u'United States',
#   u'Date Joined': u'9/1/2015',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Iconiq Capital, K1 Capital, Salesforce Ventures',
#   u'Valuation ($B)': u'1.75'},
#  {u'Company': u'Squarespace',
#   u'Country': u'United States',
#   u'Date Joined': u'12/14/2017',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'General Atlantic, Index Ventures, Accel Partners',
#   u'Valuation ($B)': u'1.7'},
#  {u'Company': u'Buzzfeed',
#   u'Country': u'United States',
#   u'Date Joined': u'8/18/2015',
#   u'Industry': u'Media',
#   u'Select Investors': u'SV Angel, RRE Ventures, New Enterprise Associates ',
#   u'Valuation ($B)': u'1.7'},
#  {u'Company': u'Revolut',
#   u'Country': u'United Kingdom',
#   u'Date Joined': u'4/26/2018',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'index Ventures, DST Global, Ribbit Capital',
#   u'Valuation ($B)': u'1.7'},
#  {u'Company': u'Carbon3D',
#   u'Country': u'United States',
#   u'Date Joined': u'12/20/2017',
#   u'Industry': u'Hardware',
#   u'Select Investors': u'Google Ventures, Sequoia Capital, Wakefield Group',
#   u'Valuation ($B)': u'1.7'},
#  {u'Company': u'UCommune',
#   u'Country': u'China',
#   u'Date Joined': u'1/18/2017',
#   u'Industry': u'Real Estate',
#   u'Select Investors': u'Ant Financial Services Group, Dahong Group, Sequoia Capital China',
#   u'Valuation ($B)': u'1.7'},
#  {u'Company': u'Insidesales.com',
#   u'Country': u'United States',
#   u'Date Joined': u'4/28/2014',
#   u'Industry': u'Big Data',
#   u'Select Investors': u'Microsoft Ventures, US Venture Partners, Kleiner Perkins Caufield & Byers',
#   u'Valuation ($B)': u'1.7'},
#  {u'Company': u'Discord',
#   u'Country': u'United States',
#   u'Date Joined': u'04/20/2018',
#   u'Industry': u'eSports',
#   u'Select Investors': u'Benchmark, Greylock Partners, Tencent Holdings',
#   u'Valuation ($B)': u'1.65'},
#  {u'Company': u'CureVac',
#   u'Country': u'United Kingdom',
#   u'Date Joined': u'5/15/2018',
#   u'Industry': u'Cybersecurity',
#   u'Select Investors': u'Kohlberg Kravis Roberts & Co., Ten Eleven Ventures, Summit Partners',
#   u'Valuation ($B)': u'1.65'},
#  {u'Company': u'Darktrace',
#   u'Country': u'Germany',
#   u'Date Joined': u'03/05/2015',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'Northview Ventures, dievini Hopp BioTech Holding & Co.m Baillie Gifford & Co.',
#   u'Valuation ($B)': u'1.65'},
#  {u'Company': u'Afiniti',
#   u'Country': u'United States',
#   u'Date Joined': u'4/14/2017',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'GAM Holding',
#   u'Valuation ($B)': u'1.6'},
#  {u'Company': u'Infinidat',
#   u'Country': u'Israel',
#   u'Date Joined': u'4/29/2015',
#   u'Industry': u'Hardware',
#   u'Select Investors': u'TPG Growth, Goldman Sachs',
#   u'Valuation ($B)': u'1.6'},
#  {u'Company': u'BlaBlaCar',
#   u'Country': u'France',
#   u'Date Joined': u'9/16/2015',
#   u'Industry': u'On-Demand',
#   u'Select Investors': u'Accel Partners, Index Ventures, Insight Venture Partners',
#   u'Valuation ($B)': u'1.6'},
#  {u'Company': u'Beijing LaKala Billing Services',
#   u'Country': u'China',
#   u'Date Joined': u'6/23/2015',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'China Continent Property & Casualty Insurance, China Renaissance Capital Investment, China Taiping Life Insurance',
#   u'Valuation ($B)': u'1.6'},
#  {u'Company': u'Coinbase',
#   u'Country': u'United States',
#   u'Date Joined': u'8/10/2017',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Y Combinator, Union Square Ventures, DFJ Growth',
#   u'Valuation ($B)': u'1.6'},
#  {u'Company': u'CAOCAO',
#   u'Country': u'China',
#   u'Date Joined': u'1/17/2018',
#   u'Industry': u'On Demand',
#   u'Select Investors': u'People Electrical Appliance Group China, Zhongrong International Trust',
#   u'Valuation ($B)': u'1.6'},
#  {u'Company': u'Gan & Lee Pharmaceuticals',
#   u'Country': u'China',
#   u'Date Joined': u'11/1/2014',
#   u'Industry': u'Biotechnology ',
#   u'Select Investors': u'Qiming Venture Partners, Goldman Sachs, Hillhouse Capital Management',
#   u'Valuation ($B)': u'1.6'},
#  {u'Company': u'TransferWise',
#   u'Country': u'United Kingdom',
#   u'Date Joined': u'1/26/2015',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'IA Ventures, Index Ventures, SV Angel',
#   u'Valuation ($B)': u'1.6'},
#  {u'Company': u'Quanergy Systems',
#   u'Country': u'United States',
#   u'Date Joined': u'8/24/2016',
#   u'Industry': u'Auto Tech',
#   u'Select Investors': u'Delphi Automotive, Samsung Ventures, Motus Ventures',
#   u'Valuation ($B)': u'1.59'},
#  {u'Company': u'Promasidor Holdings',
#   u'Country': u'South Africa',
#   u'Date Joined': u'11/8/2016',
#   u'Industry': u'Food and Beverage',
#   u'Select Investors': u'IFC, Ajinomoto',
#   u'Valuation ($B)': u'1.58'},
#  {u'Company': u'Oxford Nanopore Technologies',
#   u'Country': u'United Kingdom',
#   u'Date Joined': u'7/21/2015',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'Illumina, Invesco Perpetual, IP Group',
#   u'Valuation ($B)': u'1.55'},
#  {u'Company': u'DouyuTV',
#   u'Country': u'China',
#   u'Date Joined': u'11/20/2017',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'CMB International Capital, Nanshan Capital, Tencent Holdings',
#   u'Valuation ($B)': u'1.51'},
#  {u'Company': u'STX Entertainment',
#   u'Country': u'United States',
#   u'Date Joined': u'8/10/2016',
#   u'Industry': u'Entertainment',
#   u'Select Investors': u'Tencent, TPG Growth, Hony Capital',
#   u'Valuation ($B)': u'1.5'},
#  {u'Company': u'GuaHao (We Doctor)',
#   u'Country': u'China',
#   u'Date Joined': u'9/22/2015',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'Tencent, Morningside Group',
#   u'Valuation ($B)': u'1.5'},
#  {u'Company': u'Tujia',
#   u'Country': u'China',
#   u'Date Joined': u'6/17/2015',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'GGV Capital, QiMing Venture Partnersl',
#   u'Valuation ($B)': u'1.5'},
#  {u'Company': u'ironSource',
#   u'Country': u'Israel',
#   u'Date Joined': u'8/11/2014',
#   u'Industry': u'Mobile Software & Services',
#   u'Select Investors': u'Access Industries, Clal Industries and Investments',
#   u'Valuation ($B)': u'1.5'},
#  {u'Company': u'23andMe',
#   u'Country': u'United States',
#   u'Date Joined': u'7/3/2015',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'Google Ventures, New Enterprise Associates, MPM Capital',
#   u'Valuation ($B)': u'1.5'},
#  {u'Company': u'Snowflake Computing',
#   u'Country': u'United States',
#   u'Date Joined': u'1/25/2018',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Redpoint Ventures,Iconiq Capital, Madrona Venture Group',
#   u'Valuation ($B)': u'1.5'},
#  {u'Company': u'Nextdoor',
#   u'Country': u'United States',
#   u'Date Joined': u'3/4/2015',
#   u'Industry': u'Social',
#   u'Select Investors': u'Benchmark Capital, DAG Ventures, Insight Venture Partners',
#   u'Valuation ($B)': u'1.5'},
#  {u'Company': u'Aihuishou',
#   u'Country': u'China',
#   u'Date Joined': u'7/12/2018',
#   u'Industry': u'Marketplace',
#   u'Select Investors': u'Morningside Ventures, JD.com, Tiantu Capital',
#   u'Valuation ($B)': u'1.5'},
#  {u'Company': u'Freshworks',
#   u'Country': u'United States',
#   u'Date Joined': u'7/31/2018',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Accel, Tiger Global Management, capitalG',
#   u'Valuation ($B)': u'1.5'},
#  {u'Company': u'Hellobike',
#   u'Country': u'China',
#   u'Date Joined': u'6/01/2018',
#   u'Industry': u'Travel',
#   u'Select Investors': u'Ant Financial Services Group, GGV Capital',
#   u'Valuation ($B)': u'1.46'},
#  {u'Company': u'Tuandaiwang',
#   u'Country': u'China',
#   u'Date Joined': u'5/30/2017',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Beihai Hongtai Investment, China Minsheng Investment, Yisheng Innovation',
#   u'Valuation ($B)': u'1.46'},
#  {u'Company': u'Coocaa',
#   u'Country': u'China',
#   u'Date Joined': u'3/16/2018',
#   u'Industry': u'Consumer Hardware',
#   u'Select Investors': u'Baidu, Tencent Holdings',
#   u'Valuation ($B)': u'1.45'},
#  {u'Company': u'Gett',
#   u'Country': u'Israel',
#   u'Date Joined': u'6/7/2018',
#   u'Industry': u'On-demand',
#   u'Select Investors': u'Volkswagen, Access Industries, Vostok New Ventures',
#   u'Valuation ($B)': u'1.4'},
#  {u'Company': u'CGTZ',
#   u'Country': u'China',
#   u'Date Joined': u'2/21/2017',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Shunwei Capital Partners, China Media Group, Guangzhou Huiyin Aofeng Equity Investment Fund',
#   u'Valuation ($B)': u'1.4'},
#  {u'Company': u'Koudai Gouwu',
#   u'Country': u'China',
#   u'Date Joined': u'10/23/2014',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'New Enterprise Associates, Tiger Global management, Tencent',
#   u'Valuation ($B)': u'1.4'},
#  {u'Company': u'AvidXchange',
#   u'Country': u'United States',
#   u'Date Joined': u'6/8/2017',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Temasek Holdings, Charlotte Angel Partners, TPG Growth',
#   u'Valuation ($B)': u'1.4'},
#  {u'Company': u'Hike',
#   u'Country': u'India',
#   u'Date Joined': u'8/16/2016',
#   u'Industry': u'Social',
#   u'Select Investors': u'Foxconn, Tiger Global management, Tencent',
#   u'Valuation ($B)': u'1.4'},
#  {u'Company': u'C3 IoT',
#   u'Country': u'United States',
#   u'Date Joined': u'3/2/2017',
#   u'Industry': u'IoT',
#   u'Select Investors': u'Makena Capital Management, TPG Growth, Breyer Capital',
#   u'Valuation ($B)': u'1.4'},
#  {u'Company': u'AppLovin',
#   u'Country': u'United States',
#   u'Date Joined': u'1/1/2017',
#   u'Industry': u'Adtech',
#   u'Select Investors': u'Orient Hontai Capital, Webb Investment Network',
#   u'Valuation ($B)': u'1.4'},
#  {u'Company': u'Anaplan',
#   u'Country': u'United States',
#   u'Date Joined': u'1/14/2016',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Shasta Ventures, Granite Ventures, DFJ Growth Fund',
#   u'Valuation ($B)': u'1.4'},
#  {u'Company': u'Toast',
#   u'Country': u'United States',
#   u'Date Joined': u'7/10/2018',
#   u'Industry': u'Restaurant Tech',
#   u'Select Investors': u'Bessemer Venture Partners, Tiger Global Management, Google Ventures',
#   u'Valuation ($B)': u'1.4'},
#  {u'Company': u'DraftKings',
#   u'Country': u'United States',
#   u'Date Joined': u'7/26/2015',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Accomplice, GGV Capital, Redpoint Ventures',
#   u'Valuation ($B)': u'1.35'},
#  {u'Company': u'PagerDuty',
#   u'Country': u'United States',
#   u'Date Joined': u'9/6/2018',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Andreessen Horowitz, Harrison Metal, T. Rowe Price',
#   u'Valuation ($B)': u'1.3'},
#  {u'Company': u'Rubrik',
#   u'Country': u'United States',
#   u'Date Joined': u'4/28/2017',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Greylock Partners, Lightspeed Venture Partners, Khosla Ventures',
#   u'Valuation ($B)': u'1.3'},
#  {u'Company': u'Zeta Interactive',
#   u'Country': u'United States',
#   u'Date Joined': u'7/15/2015',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'GSO Capital Partners, Franklin Square',
#   u'Valuation ($B)': u'1.3'},
#  {u'Company': u'Peloton Interactive',
#   u'Country': u'United States',
#   u'Date Joined': u'5/24/2017',
#   u'Industry': u'Fitness',
#   u'Select Investors': u'True Ventures, Tiger Global Management, L Catterton',
#   u'Valuation ($B)': u'1.3'},
#  {u'Company': u'Docker',
#   u'Country': u'United States',
#   u'Date Joined': u'4/14/2015',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Greylock Partners, Lightspeed Venture Partners, Lowercase Capital',
#   u'Valuation ($B)': u'1.3'},
#  {u'Company': u'Swiggy',
#   u'Country': u'India',
#   u'Date Joined': u'6/21/2018',
#   u'Industry': u'On-demand',
#   u'Select Investors': u'Accel India, SAIF Partners, Norwest Venture Partners',
#   u'Valuation ($B)': u'1.3'},
#  {u'Company': u'Intercom',
#   u'Country': u'United States',
#   u'Date Joined': u'3/27/2018',
#   u'Industry': u'Sales Tech',
#   u'Select Investors': u'Social Capital, Bessemer Venture Partners',
#   u'Valuation ($B)': u'1.27'},
#  {u'Company': u'Atom Bank',
#   u'Country': u'United Kingdom',
#   u'Date Joined': u'3/7/2018',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Toscafund Asset Management, Woodford Investment Management, BBVA',
#   u'Valuation ($B)': u'1.25'},
#  {u'Company': u'Thumbtack',
#   u'Country': u'United States',
#   u'Date Joined': u'9/29/2015',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Tiger Global, Sequoia Capital, Google Capital',
#   u'Valuation ($B)': u'1.2'},
#  {u'Company': u'Ten-X',
#   u'Country': u'United States',
#   u'Date Joined': u'3/5/2014',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Stone Point Capital, Google Capital',
#   u'Valuation ($B)': u'1.2'},
#  {u'Company': u'Clover Health',
#   u'Country': u'United States',
#   u'Date Joined': u'5/10/2017',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'Google Ventures, Sequoia Capital, First Round Capital',
#   u'Valuation ($B)': u'1.2'},
#  {u'Company': u'Appnexus',
#   u'Country': u'United States',
#   u'Date Joined': u'8/18/2014',
#   u'Industry': u'Adtech',
#   u'Select Investors': u'Khosla Ventures, Technology Crossover Ventures, Tribeca Venture Partners',
#   u'Valuation ($B)': u'1.2'},
#  {u'Company': u'Warby Parker',
#   u'Country': u'United States',
#   u'Date Joined': u'4/30/2015',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'BoxGroup, Felicis Ventures, First Round Capital',
#   u'Valuation ($B)': u'1.2'},
#  {u'Company': u'Human Longevity',
#   u'Country': u'United States',
#   u'Date Joined': u'4/5/2016',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'Celgene, GE Ventures, Draper Fisher Jurvetson',
#   u'Valuation ($B)': u'1.2'},
#  {u'Company': u'OfferUp',
#   u'Country': u'United States',
#   u'Date Joined': u'9/8/2016',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Andreessen Horowitz, GGV Capital, T. Rowe Price',
#   u'Valuation ($B)': u'1.2'},
#  {u'Company': u'Careem Networks',
#   u'Country': u'United Arab Emirates',
#   u'Date Joined': u'12/18/2016',
#   u'Industry': u'On Demand',
#   u'Select Investors': u'STC Ventures, Al Tayyar Travel Group, Wamda Capital',
#   u'Valuation ($B)': u'1.2'},
#  {u'Company': u'Postmates',
#   u'Country': u'United States',
#   u'Date Joined': u'9/18/2018',
#   u'Industry': u'On Demand',
#   u'Select Investors': u'Founders Fund, Matrix Partners, Tiger Global Management',
#   u'Valuation ($B)': u'1.2'},
#  {u'Company': u'HeartFlow',
#   u'Country': u'United States',
#   u'Date Joined': u'12/4/2017',
#   u'Industry': u'Digital Health',
#   u'Select Investors': u'BlueCross BlueShield Venture Partners, US Venture Partners',
#   u'Valuation ($B)': u'1.19'},
#  {u'Company': u'Logical Thinking (Luojisiwei)',
#   u'Country': u'China',
#   u'Date Joined': u'7/20/2017',
#   u'Industry': u'Ed Tech',
#   u'Select Investors': u'Sequoia Capital China, Qiming Venture Partners, Tencent Holdings',
#   u'Valuation ($B)': u'1.17'},
#  {u'Company': u'Automattic',
#   u'Country': u'United States',
#   u'Date Joined': u'5/27/2013',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Insight Venture Partners, Lowercase Capital, Polaris Partners',
#   u'Valuation ($B)': u'1.16'},
#  {u'Company': u'NetEase Cloud Music',
#   u'Country': u'China',
#   u'Date Joined': u'4/11/2017',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u' China International Capital Corporation, Hunan TV & Broadcast Intermediary, Shanghai Media Group',
#   u'Valuation ($B)': u'1.16'},
#  {u'Company': u'LIfeMiles',
#   u'Country': u'Colombia',
#   u'Date Joined': u'7/13/2015',
#   u'Industry': u'Business Products & Services',
#   u'Select Investors': u'Advent International',
#   u'Valuation ($B)': u'1.15'},
#  {u'Company': u'Global Fashion Group',
#   u'Country': u'Luxembourg',
#   u'Date Joined': u'4/8/2015',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Access Industries, Rocket Internet, Tengelmann Ventures',
#   u'Valuation ($B)': u'1.1'},
#  {u'Company': u'Shopclues',
#   u'Country': u'India',
#   u'Date Joined': u'1/12/2016',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Nexus Venture Partners, GIC Special Investments, Tiger Global Management',
#   u'Valuation ($B)': u'1.1'},
#  {u'Company': u'Proteus Digital Health',
#   u'Country': u'United States',
#   u'Date Joined': u'6/2/2014',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'Novartis, Essex Woodlands, The Carlyle Group',
#   u'Valuation ($B)': u'1.1'},
#  {u'Company': u'Actifio',
#   u'Country': u'United States',
#   u'Date Joined': u'3/24/2014',
#   u'Industry': u'Big Data',
#   u'Select Investors': u'Greylock Partners, North Bridge Venture Partners, Technology Crossover Ventures',
#   u'Valuation ($B)': u'1.1'},
#  {u'Company': u'TangoMe',
#   u'Country': u'United States',
#   u'Date Joined': u'3/20/2014',
#   u'Industry': u'Social',
#   u'Select Investors': u'Draper Fisher Jurtson, Qualcomm Ventures, Alibaba Group',
#   u'Valuation ($B)': u'1.1'},
#  {u'Company': u'Tuhu',
#   u'Country': u'China',
#   u'Date Joined': u'12/2/2017',
#   u'Industry': u'Auto Tech',
#   u'Select Investors': u'Qiming Venture Partners, Yaxia Automobile, Far East Horizon',
#   u'Valuation ($B)': u'1.16'},
#  {u'Company': u'OVH',
#   u'Country': u'France',
#   u'Date Joined': u'7/3/2015',
#   u'Industry': u'Big Data',
#   u'Select Investors': u'Kohlberg Kravis Roberts & Co.,TowerBrook Capital Partners',
#   u'Valuation ($B)': u'1.1'},
#  {u'Company': u'Tradeshift',
#   u'Country': u'United States',
#   u'Date Joined': u'5/30/2018',
#   u'Industry': u'Fintech / Supply Chain',
#   u'Select Investors': u'Notion Capital, Scentan Ventures, Kite Ventures',
#   u'Valuation ($B)': u'1.1'},
#  {u'Company': u'Lime',
#   u'Country': u'United States',
#   u'Date Joined': u'7/9/2018',
#   u'Industry': u'Travel',
#   u'Select Investors': u'Andreessen Horowitz, Coatue Management, Uber',
#   u'Valuation ($B)': u'1.1'},
#  {u'Company': u'GitLab',
#   u'Country': u'United States',
#   u'Date Joined': u'9/19/2018',
#   u'Industry': u'DevOps',
#   u'Select Investors': u'Google Ventures, ICONIQ Capital, Khosla Ventures',
#   u'Valuation ($B)': u'1.1'},
#  {u'Company': u'Yijiupi (\u6613\u4e45\u6279)',
#   u'Country': u'China',
#   u'Date Joined': u'9/20/2018',
#   u'Industry': u'e-commerce',
#   u'Select Investors': u'Source Code Capital, Meituan Dianping, Tencent Holdings',
#   u'Valuation ($B)': u'1.1'},
#  {u'Company': u'Radius Payments Solutions',
#   u'Country': u'United Kingdom',
#   u'Date Joined': u'11/27/2017',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Inflexion Private Equity',
#   u'Valuation ($B)': u'1.07'},
#  {u'Company': u'Jiuxian',
#   u'Country': u'China',
#   u'Date Joined': u'7/30/2015',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Sequoia Capital China, Rich Land Capital, Merrysunny Wealth',
#   u'Valuation ($B)': u'1.05'},
#  {u'Company': u'Jumia',
#   u'Country': u'Nigeria',
#   u'Date Joined': u'2/8/2016',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'AXA',
#   u'Valuation ($B)': u'1.04'},
#  {u'Company': u'AppDirect',
#   u'Country': u'United States',
#   u'Date Joined': u'10/7/2015',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Mithril, iNovia Capital, Foundry Group',
#   u'Valuation ($B)': u'1.04'},
#  {u'Company': u'Avaloq Group',
#   u'Country': u'Switzerland',
#   u'Date Joined': u'3/22/2017',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Warbug Pincus',
#   u'Valuation ($B)': u'1.01'},
#  {u'Company': u'Ofo',
#   u'Country': u'China',
#   u'Date Joined': u'3/1/2017',
#   u'Industry': u'On Demand',
#   u'Select Investors': u'GSR Ventures, Matrix Partners China, Didi Chuxing',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Katerra',
#   u'Country': u'United States',
#   u'Date Joined': u'4/13/2017',
#   u'Industry': u'Construction Tech',
#   u'Select Investors': u'Foxconn Technology Company, Khosla Ventures, Moore Capital Management',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Yuanfudao',
#   u'Country': u'China',
#   u'Date Joined': u'5/31/2017',
#   u'Industry': u'Edtech',
#   u'Select Investors': u'Tencent Holdings, Warbug Pincus, IDG Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Yixia',
#   u'Country': u'China',
#   u'Date Joined': u'11/24/2015',
#   u'Industry': u'Social',
#   u'Select Investors': u'Sequoia Capital China, Sina Weibo, Kleiner Perkins Caufield & Byers, Redpoint Ventures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Medallia',
#   u'Country': u'United States',
#   u'Date Joined': u'7/21/2015',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Sequoia Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Apus Group',
#   u'Country': u'China',
#   u'Date Joined': u'1/16/2015',
#   u'Industry': u'Mobile Software & Services',
#   u'Select Investors': u'Redpoint Ventures, QiMing Venture Partners, Chengwei Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'CloudFlare',
#   u'Country': u'United States',
#   u'Date Joined': u'12/1/2012',
#   u'Industry': u'Cybersecurity',
#   u'Select Investors': u'New Enterprise Associates, Pelion Venture Partners, Union Square Ventures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Lookout',
#   u'Country': u'United States',
#   u'Date Joined': u'8/13/2014',
#   u'Industry': u'Cybersecurity',
#   u'Select Investors': u'Accel Partners, Greylock Partners, Lowercase Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Fanli',
#   u'Country': u'China',
#   u'Date Joined': u'4/20/2015',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'QiMing Venture Partners, Steam boat Ventures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Zomato Media',
#   u'Country': u'India',
#   u'Date Joined': u'4/10/2015',
#   u'Industry': u'Social',
#   u'Select Investors': u'Sequoia Capital, VY Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'TechStyle Fashion Group',
#   u'Country': u'United States',
#   u'Date Joined': u'8/29/2014',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Matrix Partners, Passport Capital, Rho Ventures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Desktop Metal',
#   u'Country': u'United States',
#   u'Date Joined': u'7/17/2017',
#   u'Industry': u'3D Printing',
#   u'Select Investors': u'Australian Future Fund, GE Ventures, Data Collective',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Illumio',
#   u'Country': u'United States',
#   u'Date Joined': u'4/14/2014',
#   u'Industry': u'Cybersecurity',
#   u'Select Investors': u'Data Collective, Formation 8, General Catalyst Partners',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'BeiBei',
#   u'Country': u'China',
#   u'Date Joined': u'1/22/2015',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Banyan Capital, New Horizon Capital, IDG Capital Partners',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Panshi',
#   u'Country': u'China',
#   u'Date Joined': u'5/5/2015',
#   u'Industry': u'Adtech',
#   u'Select Investors': u'WI Harper Group, Fang Fund Partners, NewMarging Ventures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'InMobi',
#   u'Country': u'India',
#   u'Date Joined': u'12/2/2014',
#   u'Industry': u'Adtech',
#   u'Select Investors': u'Kleiner Perkins Caufield & Byers, Softbank Corp., Sherpalo Ventures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'MarkLogic',
#   u'Country': u'United States',
#   u'Date Joined': u'5/12/2015',
#   u'Industry': u'Big Data',
#   u'Select Investors': u'Sequoia Capital, Tenaya Capital, Northgate Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Zhaogang',
#   u'Country': u'China',
#   u'Date Joined': u'6/29/2017',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'K2 Ventures, Matrix Partners China, IDG Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Vox Media',
#   u'Country': u'United States',
#   u'Date Joined': u'8/12/2015',
#   u'Industry': u'Media',
#   u'Select Investors': u'Accel Partners, Comcast Ventures, General Atlantic',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Kik Interactive',
#   u'Country': u'Canada',
#   u'Date Joined': u'8/18/2015',
#   u'Industry': u'Social',
#   u'Select Investors': u'Union Square Ventures, RRE Ventures, Spark Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'letgo',
#   u'Country': u'Netherlands',
#   u'Date Joined': u'9/28/2017',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Accel Partners, FJ Labs, Insight Venture Partners',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Kabbage',
#   u'Country': u'United States',
#   u'Date Joined': u'10/14/2015',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'BlueRun Ventures, SV Angel, Mohr Davidow Ventures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'iTutorGroup',
#   u'Country': u'China',
#   u'Date Joined': u'11/18/2015',
#   u'Industry': u'Ed Tech',
#   u'Select Investors': u'QiMing Venture Partners, Temasek Holdings, Silverlink Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Gusto',
#   u'Country': u'United States',
#   u'Date Joined': u'12/18/2015',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'General Catalyst Partners, Google Ventures, Kleiner Perkins Caufield & Byers',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Dt Dream',
#   u'Country': u'China',
#   u'Date Joined': u'6/8/2017',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Alibaba Group, China Everbright Investment Management, Yinxinggu Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Cell C',
#   u'Country': u'South Africa',
#   u'Date Joined': u'8/8/2017',
#   u'Industry': u'Telecommunications',
#   u'Select Investors': u'Blue Label Telecoms, Net1 UEPS Technologies',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Mia.com',
#   u'Country': u'China',
#   u'Date Joined': u'9/8/2015',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Sequoia Capital China, ZhenFund, K2 Ventures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'iCarbonX',
#   u'Country': u'China',
#   u'Date Joined': u'4/12/2016',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'Tencent, Vcanbio',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Symphony Communication Services Holdings',
#   u'Country': u'United States',
#   u'Date Joined': u'5/16/2017',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'BNP Paribas, Goldman Sachs, Google',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Age of Learning',
#   u'Country': u'United States',
#   u'Date Joined': u'5/3/2016',
#   u'Industry': u'Edtech',
#   u'Select Investors': u'Iconiq Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Quikr',
#   u'Country': u'India',
#   u'Date Joined': u'4/7/2015',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Brand Capital, Tiger Global Management, Kinnevik',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'SMS Assist',
#   u'Country': u'United States',
#   u'Date Joined': u'6/13/2016',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Goldman Sachs, Insights Venture Partners, Pritzker Group Venture Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'benevolent.ai ',
#   u'Country': u'United Kingdom',
#   u'Date Joined': u'6/2/2015',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'Woodford Investment Management',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Mofang Gongyu',
#   u'Country': u'China',
#   u'Date Joined': u'4/13/2016',
#   u'Industry': u'Facilities',
#   u'Select Investors': u'Warburg Pincus, Aviation Industry Corporation of China',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Adaptive Biotechnologies',
#   u'Country': u'United States',
#   u'Date Joined': u'1/8/2015',
#   u'Industry': u'Healthcare',
#   u'Select Investors': u'Illumina, Celgene, Casdin Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'HuJiang',
#   u'Country': u'China',
#   u'Date Joined': u'10/29/2015',
#   u'Industry': u'Edtech',
#   u'Select Investors': u'China Minsheng Investment, Baidu, Wanxin Media',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Guazi (Chehaoduo)',
#   u'Country': u'China',
#   u'Date Joined': u'3/12/2016',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Sequoia Capital China, GX Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Rubicon Global',
#   u'Country': u'United States',
#   u'Date Joined': u'8/25/2017',
#   u'Industry': u'Cleantech',
#   u'Select Investors': u'Goldman Sachs, Leonardo DiCaprio, Promecap ',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'YH Global',
#   u'Country': u'China',
#   u'Date Joined': u'9/21/2017',
#   u'Industry': u'Supplychain/ logistics',
#   u'Select Investors': u'Co-Energy Finance, Grandland',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Cylance',
#   u'Country': u'United States',
#   u'Date Joined': u'6/8/2016',
#   u'Industry': u'Cybersecurity',
#   u'Select Investors': u'Khosla Ventures, Fairhaven Capital, In-Q-Tel',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Rocket Lab',
#   u'Country': u'United States',
#   u'Date Joined': u'3/21/2017',
#   u'Industry': u'SpaceTech',
#   u'Select Investors': u'Lockheed Martin, Khosla Ventures, Bessemer Venture Partners',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Zoom Communications',
#   u'Country': u'United States',
#   u'Date Joined': u'1/17/2017',
#   u'Industry': u'Internet Software & Services',
#   u'Select Investors': u'Sequoia Capital, Qualcomm Ventures, Emergence Capital Partners',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Tongdun Technology',
#   u'Country': u'China',
#   u'Date Joined': u'10/10/2017',
#   u'Industry': u'Cybersecurity',
#   u'Select Investors': u'Advantech Capital, Temasek Holdings Ltd., Tiantu Capital Co.',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Supreme',
#   u'Country': u'United States',
#   u'Date Joined': u'10/9/2017',
#   u'Industry': u'Clothing & Accessories',
#   u'Select Investors': u'The Carlyle Group',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Particle',
#   u'Country': u'United States',
#   u'Date Joined': u'10/17/2017',
#   u'Industry': u'Digital Media',
#   u'Select Investors': u'Phoenix New Media',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Face++ (Megvii)',
#   u'Country': u'China',
#   u'Date Joined': u'10/31/2017',
#   u'Industry': u'AI / Facial Recognition',
#   u'Select Investors': u'Ant Financial Services Group, Russia-China Investment Fund, Foxconn Technology Company',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u' XiaoZhu ',
#   u'Country': u'China',
#   u'Date Joined': u'11/1/2017',
#   u'Industry': u'eCommerce/Marketplace',
#   u'Select Investors': u'Morningside Ventures, Capital Today, JOY Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u' Ginkgo BioWorks',
#   u'Country': u'United States',
#   u'Date Joined': u'12/14/2017',
#   u'Industry': u'Biotechnology',
#   u'Select Investors': u'Y Combinator, Data Collective, MassVentures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Canva',
#   u'Country': u'Australia',
#   u'Date Joined': u'01/08/2018',
#   u'Industry': u'Collaboration & Project Management',
#   u'Select Investors': u'Sequoia Capital China, Blackbird Ventures, Matrix Partners',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'OrCam Technologies',
#   u'Country': u'Israel',
#   u'Date Joined': u'02/21/2018',
#   u'Industry': u'Consumer Electronics',
#   u'Select Investors': u'Intel Capital, Aviv Venture Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'17zuoye ',
#   u'Country': u'China',
#   u'Date Joined': u'03/7/2018',
#   u'Industry': u'EdTech',
#   u'Select Investors': u'DST Global, Temasek Holdings',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Ding Xiang Yuan ',
#   u'Country': u'China',
#   u'Date Joined': u'04/10/2018',
#   u'Industry': u'Digital Health',
#   u'Select Investors': u'Tencent Holdings, DCM Ventures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Soundhound',
#   u'Country': u'United States',
#   u'Date Joined': u'05/03/2018',
#   u'Industry': u'Music',
#   u'Select Investors': u'Tencent Holdings, Walden Venture Capital, Global Catalyst Partnera',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Huike Group (Uniquedu Corporation)',
#   u'Country': u'China',
#   u'Date Joined': u'05/24/2018',
#   u'Industry': u'HR Tech',
#   u'Select Investors': u'Fosun RZ Capital, Oceanwide Holdings, Shenzhen Qianhe Capital Management Co.',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'JOLLY Information Technology',
#   u'Country': u'China',
#   u'Date Joined': u'05/29/2018',
#   u'Industry': u'ecommerce',
#   u'Select Investors': u'Legend Capital, CDH Investments, Sequoia Capital China',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Bird Rides',
#   u'Country': u'United States',
#   u'Date Joined': u'05/29/2018',
#   u'Industry': u'Travel',
#   u'Select Investors': u'Tusk Ventures, Craft Ventures, Sequoia Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'taxify',
#   u'Country': u'Estonia',
#   u'Date Joined': u'05/30/2018',
#   u'Industry': u'On-demand',
#   u'Select Investors': u'Didi Chuxing, Diamler, TMT Investments',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'New Dada',
#   u'Country': u'China',
#   u'Date Joined': u'12/31/2015',
#   u'Industry': u'Supply Chain Tech',
#   u'Select Investors': u'DST Global, Sequoia Capital China',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'luckin coffee',
#   u'Country': u'China',
#   u'Date Joined': u'6/13/2018',
#   u'Industry': u'Food & Beverage',
#   u'Select Investors': u'JOY Capital, Lu Zhengyao',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'PolicyBazaar',
#   u'Country': u'India',
#   u'Date Joined': u'6/25/2018',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'Info Edge, Softbank Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Celonis',
#   u'Country': u'Germany',
#   u'Date Joined': u'6/26/2018',
#   u'Industry': u'BI & Analytics',
#   u'Select Investors': u'Accel, 83North',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Dataminr',
#   u'Country': u'United States',
#   u'Date Joined': u'6/4/2018',
#   u'Industry': u'BI & Analytics',
#   u'Select Investors': u'Venrock, Institutional Venture Partners, Goldman Sachs',
#   u'Valuation ($B)': u'1.6'},
#  {u'Company': u'9f Group',
#   u'Country': u'China',
#   u'Date Joined': u'4/14/2015',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'China Cinda Asset Management, IDG Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'OutSystems',
#   u'Country': u'Portugal',
#   u'Date Joined': u'6/5/2018',
#   u'Industry': u'DevOps',
#   u'Select Investors': u'KKR, ES Ventures, North Bridge Growth Equity',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Pony.ai',
#   u'Country': u'United States',
#   u'Date Joined': u'7/11/2018',
#   u'Industry': u'AutoTech',
#   u'Select Investors': u'Sequoia Capital China, IDG Capital, DCM Ventures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'MediaMath',
#   u'Country': u'United States',
#   u'Date Joined': u'7/10/2018',
#   u'Industry': u'AdTech',
#   u'Select Investors': u'Silicon Valley Bank, QED Investors, European Founders Fund',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Tiger Brokers',
#   u'Country': u'China',
#   u'Date Joined': u'7/11/2018',
#   u'Industry': u'Fintech',
#   u'Select Investors': u'ZhenFund, China Renaissance, CreditEase Fintech Investment Fund',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'About You',
#   u'Country': u'Germany',
#   u'Date Joined': u'7/19/2018',
#   u'Industry': u'eCommerce',
#   u'Select Investors': u'German Media Pool, Seven Venture Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Revolution Precrafted',
#   u'Country': u'Philippines',
#   u'Date Joined': u'10/23/2017',
#   u'Industry': u'Construction Tech',
#   u'Select Investors': u'K2 Global, 500 Startups',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Klook',
#   u'Country': u'Hong Kong',
#   u'Date Joined': u'8/7/2018',
#   u'Industry': u'Travel Tech',
#   u'Select Investors': u'Sequoia Capital China, Goldman Sachs, Matrix Partners China',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'GoodRx',
#   u'Country': u'United States',
#   u'Date Joined': u'8/6/2018',
#   u'Industry': u'Travel Tech',
#   u'Select Investors': u'Silver Lake Partners, SV Angel, Upfront Ventures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Bukalapak',
#   u'Country': u'Indonesia',
#   u'Date Joined': u'11/16/2017',
#   u'Industry': u'eCommerce',
#   u'Select Investors': u'500 Startups, Batavia Incubator, Emtek Group',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Root Insurance',
#   u'Country': u'United States',
#   u'Date Joined': u'8/22/2018',
#   u'Industry': u'InsurTech',
#   u'Select Investors': u'Tiger Global Management, Ribbit Capital, Redpoint Ventures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Cohesity',
#   u'Country': u'United States',
#   u'Date Joined': u'6/11/2018',
#   u'Industry': u'Data Storage',
#   u'Select Investors': u'SoftBank Group, Sequoia Capital, Wing Venture Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Shansong Express (FlashEx)',
#   u'Country': u'China',
#   u'Date Joined': u'8/27/2018',
#   u'Industry': u'Supply Chain & Logistics',
#   u'Select Investors': u'Prometheus Capital, Matrix Partners China, JD Capital Management',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u"BYJU'S",
#   u'Country': u'India',
#   u'Date Joined': u'8/27/2018',
#   u'Industry': u'Ed Tech',
#   u'Select Investors': u'Tencent Holdings, Lightsepeed India Partners, Sequoia Capital India',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Udaan',
#   u'Country': u'India',
#   u'Date Joined': u'9/3/2018',
#   u'Industry': u'e-commerce',
#   u'Select Investors': u'DST Global, Lightspeed Venture Partners, Microsoft ScaleUp',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Rappi',
#   u'Country': u'Colombia',
#   u'Date Joined': u'8/31/2018',
#   u'Industry': u'On-demand',
#   u'Select Investors': u'DST Global, Andreessen Horowitz, Sequoia Capital, Redpoint e.ventures',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Xinyang Technology (SoYoung)',
#   u'Country': u'China',
#   u'Date Joined': u'9/4/2018',
#   u'Industry': u'e-commerce',
#   u'Select Investors': u'Orchid Asia Group Management, Russia-China Investment Fund, Matrix Partners China',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Roblox',
#   u'Country': u'United States',
#   u'Date Joined': u'9/4/2018',
#   u'Industry': u'Gaming',
#   u'Select Investors': u'Atlos Ventures, Index Ventures, First Round Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Aijia Life',
#   u'Country': u'China',
#   u'Date Joined': u'9/17/2018',
#   u'Industry': u'Construction Tech',
#   u'Select Investors': u'Tiantu Capital, Fortune Capital, Zhenghedao Fund',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Nxin (\u519c\u4fe1\u4e92\u8054)',
#   u'Country': u'China',
#   u'Date Joined': u'9/18/2018',
#   u'Industry': u'Ag Tech',
#   u'Select Investors': u'Beijing Juneng Hesheng Industry Investment Fund, Beijing Shuju Xinrong Fund',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'WalkMe',
#   u'Country': u'United States',
#   u'Date Joined': u'9/20/2018',
#   u'Industry': u'Sales Tech',
#   u'Select Investors': u'Gemini Israel Ventures, Insight Venture Partners, Giza Venture Capital',
#   u'Valuation ($B)': u'1'},
#  {u'Company': u'Convoy',
#   u'Country': u'United States',
#   u'Date Joined': u'9/21/2018',
#   u'Industry': u'Supply Chain',
#   u'Select Investors': u'Greylock Partners, capitalG, Y Combinator',
#   u'Valuation ($B)': u'1'}]

# %% [markdown]
# # Option 1 - Query through Kibana DevTool Console

# %% [markdown]
# ### Create json file for bulk import

# %%
"""In order to create json file for bulk import, we shall add action data for each index"""

action_list = []
for i in range(len(unicorn)):
    # create index for each entry
    action = { "index" : { "_index" : "unicorn", "_type" : "default", "_id" : i+1 } }
    action_list.append(action)

# %%
"""create json file in specific format for bulk API"""
## action_and_meta_data\n
## optional_source\n

with open('unicorn.json', 'w') as outfile:
    for (idx, line) in zip(action_list, unicorn):
        json.dump(idx, outfile)
        outfile.write('\n')
        json.dump(line, outfile)
        outfile.write('\n')

# %% [markdown]
# ### Create index and mappings

# %% [markdown]
# PUT /unicorn
#
# {
#   "mappings":{
#
#     "default":{
#       "properties": {
#         "Company":{
#           "type": "text"
#         },
#
#         "Country":{
#           "type": "text",
#           "fields": {
#             "keyword":{
#               "type": "keyword"
#             }
#           }
#         },
#
#         "Date Joined":{
#           "type": "date",
#           "format": "MM/dd/yyyy"
#         },
#         "Industry":{
#           "type": "text",
#         },
#         "Select Investors":{
#           "type": "text",
#           "fields": {
#             "keyword":{
#               "type": "text"
#             }
#           }
#         },
#         "Valuation ($B)": {
#           "type": "float"
#         }
#       }
#     }
#   }
# }

# %% [markdown]
# ### Index documents via bulk

# %% [markdown]
#  $ curl -s -H "Content-Type: application/xOST localhost:9200/unicorn/_bulk --data-binary "@unicorn.json"

# %% [markdown]
# ### Query Examples

# %% [markdown]
# """ we can use Kibana Devtool to do the query"""
#
# GET /unicorn/default/_search
#
# {
#   "size": 0,
#   "aggs": {
#     "date_range": {
#       "range": {
#         "field": "Date Joined",
#         "ranges": [
#           {
#             "to": "01/01/2017||+1y",
#             "from": "01/01/2017"
#
#           }
#         ]
#       }
#     }
#   }
# }

# %% [markdown]
# # Option 2 - Query by ES Python API

# %% [markdown]
# ### Create Index

# %%
def create_index(es_object, index_name):
    created = False
    # index settings
    settings = {
        "settings": {
            "number_of_shards": 1,
            "number_of_replicas": 0
        },
    "mappings": {
    "default":{
      "dynamic": "strict",
      "properties": {
       "Company":{
          "type": "text"
        },
        
        "Country":{
          "type": "text",
          "fields": {
            "keyword":{
              "type": "keyword"
            }
          }
        },
        
        "Date Joined":{
          "type": "date",
          "format": "MM/dd/yyyy"
        },
        "Industry":{
          "type": "text",
        },
        "Select Investors":{
          "type": "text",
          "fields": {
            "keyword":{
              "type": "text"
            }
          }
        },
        "Valuation ($B)": {
          "type": "float"
        }
      }
    }
  }
}


    try:
        if not es_object.indices.exists(index_name):
            # Ignore 400 means to ignore "Index Already Exist" error.
            es_object.indices.create(index=index_name, ignore=400, body=settings)
            print('Created Index')
        created = True
    except Exception as ex:
        print(str(ex))
    finally:
        return created

# %%
def store_record(elastic_object, index_name, idx, record):
    is_stored = True
    try:
        outcome = elastic_object.index(index=index_name, doc_type='default', id= idx, body=record)
        print(outcome)
    except Exception as ex:
        print('Error in indexing data')
        print(str(ex))
        is_stored = False
    finally:
        return is_stored

# %%
def connect_elasticsearch():
    _es = None
    _es = Elasticsearch([{'host': 'localhost', 'port': 9200}])
    if _es.ping():
        print('Yay Connected')
    else:
        print('Awww it could not connect!')
    return _es

# %%
def search(es_object, index_name, search ):
    res = es_object.search(index = index_name, body = search)
    pprint(res)

# %% [markdown]
# ### Adds document in a specific index

# %%
es = connect_elasticsearch()

for idx, row in enumerate(unicorn):
    if es is not None:
        if create_index(es, 'unicorn'):
            out = store_record(es, 'unicorn', idx, row)
            print('Data indexed successfully')
# Out:
# Yay Connected
# {u'_type': u'default', u'_seq_no': 261, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'0'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 262, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'1'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 263, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'2'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 264, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'3'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 265, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'4'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 266, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'5'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 267, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'6'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 268, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'7'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 269, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'8'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 270, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'9'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 271, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'10'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 272, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'11'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 273, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'12'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 274, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'13'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 275, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'14'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 276, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'15'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 277, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'16'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 278, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'17'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 279, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'18'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 280, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'19'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 281, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'20'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 282, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'21'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 283, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'22'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 284, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'23'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 285, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'24'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 286, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'25'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 287, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'26'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 288, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'27'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 289, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'28'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 290, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'29'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 291, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'30'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 292, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'31'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 293, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'32'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 294, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'33'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 295, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'34'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 296, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'35'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 297, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'36'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 298, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'37'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 299, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'38'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 300, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'39'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 301, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'40'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 302, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'41'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 303, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'42'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 304, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'43'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 305, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'44'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 306, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'45'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 307, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'46'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 308, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'47'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 309, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'48'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 310, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'49'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 311, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'50'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 312, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'51'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 313, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'52'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 314, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'53'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 315, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'54'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 316, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'55'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 317, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'56'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 318, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'57'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 319, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'58'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 320, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'59'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 321, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'60'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 322, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'61'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 323, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'62'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 324, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'63'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 325, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'64'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 326, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'65'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 327, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'66'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 328, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'67'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 329, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'68'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 330, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'69'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 331, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'70'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 332, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'71'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 333, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'72'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 334, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'73'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 335, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'74'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 336, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'75'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 337, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'76'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 338, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'77'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 339, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'78'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 340, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'79'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 341, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'80'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 342, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'81'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 343, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'82'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 344, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'83'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 345, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'84'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 346, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'85'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 347, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'86'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 348, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'87'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 349, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'88'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 350, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'89'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 351, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'90'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 352, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'91'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 353, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'92'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 354, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'93'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 355, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'94'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 356, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'95'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 357, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'96'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 358, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'97'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 359, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'98'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 360, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'99'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 361, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'100'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 362, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'101'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 363, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'102'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 364, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'103'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 365, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'104'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 366, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'105'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 367, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'106'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 368, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'107'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 369, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'108'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 370, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'109'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 371, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'110'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 372, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'111'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 373, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'112'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 374, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'113'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 375, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'114'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 376, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'115'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 377, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'116'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 378, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'117'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 379, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'118'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 380, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'119'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 381, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'120'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 382, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'121'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 383, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'122'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 384, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'123'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 385, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'124'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 386, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'125'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 387, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'126'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 388, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'127'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 389, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'128'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 390, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'129'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 391, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'130'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 392, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'131'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 393, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'132'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 394, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'133'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 395, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'134'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 396, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'135'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 397, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'136'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 398, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'137'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 399, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'138'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 400, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'139'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 401, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'140'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 402, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'141'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 403, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'142'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 404, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'143'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 405, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'144'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 406, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'145'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 407, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'146'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 408, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'147'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 409, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'148'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 410, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'149'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 411, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'150'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 412, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'151'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 413, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'152'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 414, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'153'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 415, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'154'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 416, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'155'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 417, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'156'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 418, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'157'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 419, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'158'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 420, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'159'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 421, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'160'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 422, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'161'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 423, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'162'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 424, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'163'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 425, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'164'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 426, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'165'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 427, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'166'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 428, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'167'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 429, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'168'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 430, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'169'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 431, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'170'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 432, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'171'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 433, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'172'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 434, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'173'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 435, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'174'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 436, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'175'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 437, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'176'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 438, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'177'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 439, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'178'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 440, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'179'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 441, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'180'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 442, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'181'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 443, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'182'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 444, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'183'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 445, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'184'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 446, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'185'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 447, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'186'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 448, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'187'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 449, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'188'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 450, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'189'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 451, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'190'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 452, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'191'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 453, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'192'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 454, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'193'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 455, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'194'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 456, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'195'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 457, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'196'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 458, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'197'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 459, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'198'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 460, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'199'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 461, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'200'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 462, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'201'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 463, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'202'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 464, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'203'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 465, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'204'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 466, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'205'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 467, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'206'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 468, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'207'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 469, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'208'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 470, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'209'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 471, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'210'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 472, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'211'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 473, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'212'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 474, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'213'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 475, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'214'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 476, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'215'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 477, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'216'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 478, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'217'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 479, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'218'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 480, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'219'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 481, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'220'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 482, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'221'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 483, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'222'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 484, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'223'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 485, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'224'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 486, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'225'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 487, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'226'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 488, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'227'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 489, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'228'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 490, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'229'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 491, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'230'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 492, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'231'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 493, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'232'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 494, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'233'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 495, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'234'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 496, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'235'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 497, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'236'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 498, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'237'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 499, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'238'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 500, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'239'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 501, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'240'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 502, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'241'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 503, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'242'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 504, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'243'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 505, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'244'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 506, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'245'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 507, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'246'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 508, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'247'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 509, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'248'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 510, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'249'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 511, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'250'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 512, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'251'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 513, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'252'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 514, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'253'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 515, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'254'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 516, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'255'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 517, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'256'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 518, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'257'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 519, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'258'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 520, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'259'}
# Data indexed successfully
# {u'_type': u'default', u'_seq_no': 521, u'_shards': {u'successful': 1, u'failed': 0, u'total': 1}, u'_index': u'unicorn', u'_version': 2, u'_primary_term': 1, u'result': u'updated', u'_id': u'260'}
# Data indexed successfully

# %% [markdown]
# ### Execute search requests

# %%
es = connect_elasticsearch()

search_object_1 = {
  "query":{
    "match": {
    "Country": "United States"
    }
  }
}


search_object_2 = {
  "query": {
    "match": {
      "Select Investors.keyword":  "SoftBank Group"
      }
    }
  }


search(es, 'unicorn', search_object_2)
# Out:
# Yay Connected
# {u'_shards': {u'failed': 0, u'skipped': 0, u'successful': 1, u'total': 1},
#  u'hits': {u'hits': [{u'_id': u'20',
#                       u'_index': u'unicorn',
#                       u'_score': 5.964426,
#                       u'_source': {u'Company': u'Manbang Group',
#                                    u'Country': u'China',
#                                    u'Date Joined': u'4/24/2018',
#                                    u'Industry': u'Supply chain & Logistics',
#                                    u'Select Investors': u'Softbank Group, CapitalG',
#                                    u'Valuation ($B)': u'6'},
#                       u'_type': u'default'},
#                      {u'_id': u'30',
#                       u'_index': u'unicorn',
#                       u'_score': 4.787507,
#                       u'_source': {u'Company': u'Fanatics',
#                                    u'Country': u'United States',
#                                    u'Date Joined': u'6/6/2012',
#                                    u'Industry': u'eCommerce/Marketplace',
#                                    u'Select Investors': u'SoftBank Group, Andreessen Horowitz, Temasek Holdings',
#                                    u'Valuation ($B)': u'4.5'},
#                       u'_type': u'default'},
#                      {u'_id': u'36',
#                       u'_index': u'unicorn',
#                       u'_score': 4.787507,
#                       u'_source': {u'Company': u'Olacabs',
#                                    u'Country': u'India',
#                                    u'Date Joined': u'10/27/2014',
#                                    u'Industry': u'On-demand',
#                                    u'Select Investors': u'Accel Partners, SoftBank Group, Sequoia Capital',
#                                    u'Valuation ($B)': u'4.3'},
#                       u'_type': u'default'},
#                      {u'_id': u'39',
#                       u'_index': u'unicorn',
#                       u'_score': 4.787507,
#                       u'_source': {u'Company': u'DoorDash',
#                                    u'Country': u'United States',
#                                    u'Date Joined': u'3/1/2018',
#                                    u'Industry': u'Food Delivery',
#                                    u'Select Investors': u'Softbank Group, Sequoia Capital, Khosla Ventures',
#                                    u'Valuation ($B)': u'4'},
#                       u'_type': u'default'},
#                      {u'_id': u'85',
#                       u'_index': u'unicorn',
#                       u'_score': 4.787507,
#                       u'_source': {u'Company': u'Improbable',
#                                    u'Country': u'United Kingdom',
#                                    u'Date Joined': u'5/12/2017',
#                                    u'Industry': u'AR/VR',
#                                    u'Select Investors': u'Andreessen Horowitz, SoftBank Group, Temasek Holdings',
#                                    u'Valuation ($B)': u'2'},
#                       u'_type': u'default'},
#                      {u'_id': u'5',
#                       u'_index': u'unicorn',
#                       u'_score': 4.4920454,
#                       u'_source': {u'Company': u'WeWork',
#                                    u'Country': u'United States',
#                                    u'Date Joined': u'2/3/2014',
#                                    u'Industry': u'Facilities',
#                                    u'Select Investors': u'T. Rowe Price, Benchmark Capital, SoftBank Group',
#                                    u'Valuation ($B)': u'20'},
#                       u'_type': u'default'},
#                      {u'_id': u'12',
#                       u'_index': u'unicorn',
#                       u'_score': 4.4920454,
#                       u'_source': {u'Company': u'GrabTaxi',
#                                    u'Country': u'Singapore',
#                                    u'Date Joined': u'12/4/2014',
#                                    u'Industry': u'On-Demand',
#                                    u'Select Investors': u'GGV Capital, Vertex Venture Holdings, Softbank Group',
#                                    u'Valuation ($B)': u'11'},
#                       u'_type': u'default'},
#                      {u'_id': u'250',
#                       u'_index': u'unicorn',
#                       u'_score': 4.4920454,
#                       u'_source': {u'Company': u'Cohesity',
#                                    u'Country': u'United States',
#                                    u'Date Joined': u'6/11/2018',
#                                    u'Industry': u'Data Storage',
#                                    u'Select Investors': u'SoftBank Group, Sequoia Capital, Wing Venture Capital',
#                                    u'Valuation ($B)': u'1'},
#                       u'_type': u'default'},
#                      {u'_id': u'28',
#                       u'_index': u'unicorn',
#                       u'_score': 4.230933,
#                       u'_source': {u'Company': u'Oyo Rooms',
#                                    u'Country': u'India',
#                                    u'Date Joined': u'9/25/2018',
#                                    u'Industry': u'Travel Tech',
#                                    u'Select Investors': u'SoftBank Group, Sequoia Capital India,Lightspeed India Partners',
#                                    u'Valuation ($B)': u'5'},
#                       u'_type': u'default'},
#                      {u'_id': u'41',
#                       u'_index': u'unicorn',
#                       u'_score': 3.998509,
#                       u'_source': {u'Company': u'Auto1 Group',
#                                    u'Country': u'Germany',
#                                    u'Date Joined': u'8/3/2015',
#                                    u'Industry': u'eCommerce/Marketplace',
#                                    u'Select Investors': u'Digital Sky Technologies, Piton Capital, DN Capital, SoftBank Group',
#                                    u'Valuation ($B)': u'3.54'},
#                       u'_type': u'default'}],
#            u'max_score': 5.964426,
#            u'total': 50},
#  u'timed_out': False,
#  u'took': 1}
